# %%
import requests
import json
import os
import pydicom
from pydicom.dataelem import DataElement
import base64
import glob
from pathlib import Path
import matplotlib.pyplot as plt
from presidio_image_redactor import DicomImageRedactorEngine
import datetime
from PIL import Image, ImageDraw, ImageFont
import numpy as np

# %%
import cv2
import numpy as np

def draw_text_on_image_opencv(image_array, text, position=(10, 30), font_scale=1, font_color=(255, 255, 255), thickness=2, font=cv2.FONT_HERSHEY_SIMPLEX):
    """
    Draws text on a NumPy array representing an image using OpenCV.

    Args:
        image_array (numpy.ndarray): The image as a NumPy array (e.g., shape (height, width, 3) for RGB).
        text (str): The text to draw.
        position (tuple): The (x, y) coordinates of the text's bottom-left corner.
        font_scale (float): The font scale factor.
        font_color (tuple): The BGR color of the text (e.g., (0, 0, 255) for red).
        thickness (int): The thickness of the text lines.
        font (int): The OpenCV font type (e.g., cv2.FONT_HERSHEY_SIMPLEX).

    Returns:
        numpy.ndarray: The modified image as a NumPy array.
    """
    try:
        # OpenCV uses BGR color format, so we reverse the RGB tuple
        bgr_color = (font_color[2], font_color[1], font_color[0])

        # Draw the text using cv2.putText()
        cv2.putText(image_array, text, position, font, font_scale, bgr_color, thickness)

        return image_array

    except Exception as e:
        print(f"Error drawing text: {e}")
        return image_array

# %%
# Load in and process your DICOM file as needed
dicom_instance = pydicom.dcmread('dicom/manifest-1617826161202/Pseudo-PHI-DICOM-Data/Pseudo-PHI-001/06-26-2003-NA-XR CHEST AP PORTABLE-96544/1002.000000-NA-96023/1-1.dcm')
_dicom_instance = pydicom.dcmread('dicom/manifest-1617826161202/Pseudo-PHI-DICOM-Data/Pseudo-PHI-021/03-30-1987-NA-MRI ABDOMEN PELVIS WWO CONT-29432/16.000000-LIVER-PELVISHASTESAGPOS-56660/1-09.dcm')

# %%
dicom_instance.pixel_array.shape, _dicom_instance.pixel_array.shape
# Out:
# ((1760, 2140), (256, 256))

# %%
# Single DICOM (.dcm) file or directory containing DICOM files
input_path = 'dicom/'

# Directory where the output will be written
output_parent_dir = 'output/'

engine = DicomImageRedactorEngine()

# %%
dicom_instance.PatientBirthDate="19690414"
dicom_instance.PatientName="Juan Huertas"
dicom_instance
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 204
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.265811167095300800838686837893
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002,0013) Implementation Version Name         SH: '0.5'
# (0002,0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008,0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', 'RT', '', '', '', '', '100000']
# (0008,0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.265811167095300800838686837893
# (0008,0020) Study Date                          DA: '20030626'
# (0008,0021) Series Date                         DA: '20030626'
# (0008,0022) Acquisition Date                    DA: '20030626'
# (0008,0023) Content Date                        DA: '20030626'
# (0008,0030) Study Time                          TM: '085957'
# (0008,0031) Series Time                         TM: '090020.000'
# (0008,0032) Acquisition Time                    TM: '090020.408'
# (0008,0033) Content Time                        TM: '090143.249'
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'CR'
# (0008,0070) Manufacturer                        LO: 'FUJIFILM Corporation'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1030) Study Description                   LO: 'XR CHEST AP PORTABLE'
# (0008,1032)  Procedure Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'CHESTAPPAP'
#    (0008,0102) Coding Scheme Designator            SH: 'SECTRA'
#    (0008,0104) Code Meaning                        LO: 'XR CHEST AP PORTABLE'
#    ---------
# (0008,2111) Derivation Description              ST: 'G1.0e#1.60+0.20,MDR0.2AM0.6'
# (0009,0010) Private Creator                     LO: 'FDMS 1.0'
# (0010,0010) Patient's Name                      PN: 'Juan Huertas'
# (0010,0020) Patient ID                          LO: 'Pseudo-PHI-001'
# (0010,0030) Patient's Birth Date                DA: '19690414'
# (0010,0040) Patient's Sex                       CS: 'M'
# (0010,1010) Patient's Age                       AS: '037Y'
# (0012,0050) Clinical Trial Time Point ID        LO: ''
# (0012,0062) Patient Identity Removed            CS: 'YES'
# (0012,0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012,0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008,0100) Code Value                          SH: '113100'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008,0100) Code Value                          SH: '113101'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113104'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113105'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113107'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113108'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113109'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113111'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013,0010) Private Creator                     LO: 'CTP'
# (0013,1010) Private tag data                    UN: Array of 22 elements
# (0013,1013) Private tag data                    UN: b'87009668'
# (0018,0010) Contrast/Bolus Agent                LO: ''
# (0018,0015) Body Part Examined                  CS: 'CHEST'
# (0018,1020) Software Versions                   LO: 'DR-ID 300CL APL Software V7.4.0017'
# (0018,1164) Imager Pixel Spacing                DS: [0.20, 0.20]
# (0018,1400) Acquisition Device Processing Descr LO: 'CHEST AP PORT X-WISE GRID'
# (0018,1401) Acquisition Device Processing Code  LO: '0200'
# (0018,1411) Exposure Index                      DS: '319'
# (0018,1412) Target Exposure Index               DS: '876'
# (0018,1413) Deviation Index                     DS: '-4.4'
# (0018,1508) Positioner Type                     CS: 'NONE'
# (0018,5101) View Position                       CS: ''
# (0018,6000) Sensitivity                         DS: '318'
# (0018,7006) Detector Description                LT: 'Fcr'
# (0018,700A) Detector ID                         SH: ''
# (0018,A001)  Contributing Equipment Sequence  1 item(s) ----
#    (0008,0070) Manufacturer                        LO: 'SECTRA'
#    (0018,A002) Contribution DateTime               DT: '20030626'
#    (0040,A170)  Purpose of Reference Code Sequence  1 item(s) ----
#       (0008,0100) Code Value                          SH: '109103'
#       (0008,0102) Coding Scheme Designator            SH: 'DCM'
#       (0008,0104) Code Meaning                        LO: 'Modifying Equipment'
#       ---------
#    ---------
# (0019,0010) Private Creator                     LO: 'FDMS 1.0'
# (0020,000D) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.289834788775974734227766096544
# (0020,000E) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.334418705549879145080284996023
# (0020,0010) Study ID                            SH: ''
# (0020,0011) Series Number                       IS: '1002'
# (0020,0012) Acquisition Number                  IS: '3'
# (0020,0013) Instance Number                     IS: '1002'
# (0020,0020) Patient Orientation                 CS: ''
# (0020,0060) Laterality                          CS: ''
# (0021,0010) Private Creator                     LO: 'FDMS 1.0'
# (0025,0010) Private Creator                     LO: 'FDMS 1.0'
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028,0010) Rows                                US: 1760
# (0028,0011) Columns                             US: 2140
# (0028,0030) Pixel Spacing                       DS: [0.20, 0.20]
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 10
# (0028,0102) High Bit                            US: 9
# (0028,0103) Pixel Representation                US: 0
# (0028,0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028,1050) Window Center                       DS: '511'
# (0028,1051) Window Width                        DS: '1023'
# (0028,1052) Rescale Intercept                   DS: '0'
# (0028,1053) Rescale Slope                       DS: '1'
# (0028,1054) Rescale Type                        LO: 'US'
# (0028,2110) Lossy Image Compression             CS: '00'
# (0029,0010) Private Creator                     LO: 'FDMS 1.0'
# (0040,0260)  Performed Protocol Code Sequence  1 item(s) ----
#    (0008,0100) Code Value                          SH: 'FCR0200-0011'
#    (0008,0102) Coding Scheme Designator            SH: 'Fuji Standard'
#    (0008,0104) Code Meaning                        LO: 'CHEST AP PORT X-WISE GRID'
#    ---------
# (2010,0010) Image Display Format                ST: 'STANDARD\\1,1'
# (2010,0030) Annotation Display Format ID        CS: 'CR00'
# (2010,0040) Film Orientation                    CS: 'LANDSCAPE'
# (2010,0100) Border Density                      CS: 'BLACK'
# (2010,0140) Trim                                CS: 'NO'
# (7FE0,0010) Pixel Data                          OW: Array of 7532800 elements

# %% [markdown]
# # Write Text on the Image

# %%
position = (20, 80)
font_scale = 2.0
font_color = (0, 0, 0)  # Red (BGR)
thickness = 4
font = cv2.FONT_HERSHEY_SIMPLEX # Change font if desired

# %%
#modified_image_array = draw_text_on_image(dicom_instance.pixel_array, str(dicom_instance.PatientName), position, font_size, text_color, font_path)

modified_image_array = draw_text_on_image_opencv(dicom_instance.pixel_array, str(dicom_instance.PatientName), position, font_scale, font_color, thickness, font)

# %%
dicom_instance.PixelData  = modified_image_array.tostring()
# Out:
# /tmp/ipykernel_27903/45205219.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   dicom_instance.PixelData  = modified_image_array.tostring()

# %%
position = (20, 140)
modified_image_array = draw_text_on_image_opencv(dicom_instance.pixel_array, str(dicom_instance.PatientBirthDate), position, font_scale, font_color, thickness, font)
dicom_instance.PixelData  = modified_image_array.tostring()
# Out:
# /tmp/ipykernel_27903/2655477270.py:3: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   dicom_instance.PixelData  = modified_image_array.tostring()

# %%
plt.figure(figsize=(10,10))
plt.imshow(dicom_instance.pixel_array)

# %%
dicom_instance.save_as("modified_dcm.dcm")

# %%
dicom_instance2 = pydicom.dcmread("modified_dcm.dcm")
dicom_instance3 = pydicom.dcmread("1-13.dcm")
dicom_instance3 = pydicom.dcmread("1-10.dcm")
dicom_instance3 = pydicom.dcmread("1-1.dcm")
dicom_instance3 = pydicom.dcmread("1-09.dcm")
dicom_instance3 = pydicom.dcmread("output/dicon_online2/manifest-1617826161202/Pseudo-PHI-DICOM-Data/Pseudo-PHI-003/06-23-2009-NA-DBT Reconstructed Volume-26762/DBT slices-10182/02-01.dcm")

# %%
dicom_instance3
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 204
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.940967188228602337603209140117
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002,0013) Implementation Version Name         SH: '0.5'
# (0002,0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008,0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.940967188228602337603209140117
# (0008,0020) Study Date                          DA: '20090623'
# (0008,0030) Study Time                          TM: '1200'
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'MG'
# (0008,0064) Conversion Type                     CS: 'SYN'
# (0008,0068) Presentation Intent Type            CS: 'FOR PROCESSING'
# (0008,0070) Manufacturer                        LO: 'VICTRE'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1030) Study Description                   LO: 'DBT Reconstructed Volume'
# (0008,103E) Series Description                  LO: 'DBT slices'
# (0008,2111) Derivation Description              ST: 'float64 to uint16 bit conversion'
# (0010,0010) Patient's Name                      PN: 'Donald Hickman'
# (0010,0020) Patient ID                          LO: '123456'
# (0010,0030) Patient's Birth Date                DA: '20190823'
# (0010,0040) Patient's Sex                       CS: 'M'
# (0010,1020) Patient's Size                      DS: '180'
# (0010,1030) Patient's Weight                    DS: '180'
# (0010,1040) Patient's Address                   LO: '123 Main St'
# (0010,2154) Patient's Telephone Numbers         SH: '123-456-7890'
# (0010,2180) Occupation                          SH: 'Administrator ed'
# (0010,4000) Patient Comments                    LT: Array of 21 elements
# (0012,0050) Clinical Trial Time Point ID        LO: ''
# (0012,0062) Patient Identity Removed            CS: 'YES'
# (0012,0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012,0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008,0100) Code Value                          SH: '113100'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008,0100) Code Value                          SH: '113101'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113104'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113105'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113107'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113108'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113109'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008,0100) Code Value                          SH: '113111'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013,0010) Private Creator                     LO: 'CTP'
# (0013,1010) Private tag data                    UN: Array of 22 elements
# (0013,1013) Private tag data                    UN: b'87009668'
# (0018,0015) Body Part Examined                  CS: 'BREAST'
# (0018,0060) KVP                                 DS: '30'
# (0018,1110) Distance Source to Detector         DS: '650'
# (0018,1111) Distance Source to Patient          DS: '630'
# (0018,1160) Filter Type                         SH: 'FLAT'
# (0018,1164) Imager Pixel Spacing                DS: [0.085, 0.085]
# (0018,1191) Anode Target Material               CS: 'TUNGSTEN'
# (0018,11A0) Body Part Thickness                 DS: '55'
# (0018,1508) Positioner Type                     CS: 'MAMMOGRAPHIC'
# (0018,7004) Detector Type                       CS: 'DIRECT'
# (0018,7005) Detector Configuration              CS: 'AREA'
# (0018,7006) Detector Description                LT: 'a-Se, 200 micron'
# (0018,7024) Detector Active Shape               CS: 'RECTANGLE'
# (0018,7050) Filter Material                     CS: 'RHODIUM'
# (0018,7052) Filter Thickness Minimum            DS: '0.050'
# (0018,9332) Exposure in mAs                     FD: 5.1
# (0020,000D) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.335164400794092452975461126762
# (0020,000E) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.346370662838604699615308810182
# (0020,0010) Study ID                            SH: ''
# (0020,0011) Series Number                       IS: None
# (0020,0012) Acquisition Number                  IS: '2'
# (0020,0013) Instance Number                     IS: '2'
# (0020,0020) Patient Orientation                 CS: ['P', 'H']
# (0020,0062) Image Laterality                    CS: 'R'
# (0020,1002) Images in Acquisition               IS: '57'
# (0020,4000) Image Comments                      LT: 'SP'
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0010) Rows                                US: 1421
# (0028,0011) Columns                             US: 1024
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 16
# (0028,0102) High Bit                            US: 15
# (0028,0103) Pixel Representation                US: 0
# (0028,0106) Smallest Image Pixel Value          US: 0
# (0028,0107) Largest Image Pixel Value           US: 65535
# (0028,0301) Burned In Annotation                CS: 'NO'
# (0028,0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028,1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028,1041) Pixel Intensity Relationship Sign   SS: 1
# (0028,1052) Rescale Intercept                   DS: '0'
# (0028,1053) Rescale Slope                       DS: '1'
# (0028,1054) Rescale Type                        LO: 'US'
# (0028,2110) Lossy Image Compression             CS: '00'
# (0038,0500) Patient State                       LO: 'Signal present'
# (0040,0318) Organ Exposed                       CS: 'BREAST'
# (0040,0555)  Acquisition Context Sequence  0 item(s) ----
# (0054,0220)  View Code Sequence  0 item(s) ----
# (2050,0020) Presentation LUT Shape              CS: 'IDENTITY'
# (7FE0,0010) Pixel Data                          OW: Array of 2910208 elements

# %%
plt.figure(figsize=(10,10))
plt.imshow(dicom_instance3.pixel_array)

# %%
dicom_instance3 = pydicom.dcmread("dicom2/0002.DCM")

# %%
dicom_instance3
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 150
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: X-Ray Angiographic Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.4.3.321890.19960124.162922.29
# (0002,0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002,0012) Implementation Class UID            UI: 999.999
# -------------------------------------------------
# (0008,0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'SINGLE PLANE', 'SINGLE A']
# (0008,0016) SOP Class UID                       UI: X-Ray Angiographic Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.4.3.321890.19960124.162922.29
# (0008,0020) Study Date                          DA: '19941013'
# (0008,0030) Study Time                          TM: '141917'
# (0008,0050) Accession Number                    SH: ''
# (0008,0060) Modality                            CS: 'XA'
# (0008,0070) Manufacturer                        LO: ''
# (0008,0080) Institution Name                    LO: ''
# (0008,0081) Institution Address                 ST: ''
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1030) Study Description                   LO: ''
# (0008,1050) Performing Physician's Name         PN: ''
# (0008,2110) Lossy Image Compression (Retired)   CS: '01'
# (0008,2112)  Source Image Sequence  1 item(s) ----
#    (0008,1150) Referenced SOP Class UID            UI: X-Ray Angiographic Image Storage
#    (0008,1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.4.3.321890.19960124.162922.28
#    ---------
# (0009,0010) Private Creator                     LO: 'CARDIO-SMS 1.0'
# (0009,1002) [Private Data]                      OB: Array of 904 elements
# (0009,1003) [Private Data]                      OB: Array of 528 elements
# (0009,1005) [Private Data]                      OB: Array of 24 elements
# (0010,0010) Patient's Name                      PN: 'Rubo DEMO'
# (0010,0020) Patient ID                          LO: '556342B'
# (0010,0030) Patient's Birth Date                DA: '19951025'
# (0010,0040) Patient's Sex                       CS: 'M'
# (0018,0060) KVP                                 DS: None
# (0018,1063) Frame Time                          DS: '33'
# (0018,1152) Exposure                            IS: None
# (0018,1155) Radiation Setting                   CS: 'GR'
# (0018,1500) Positioner Motion                   CS: ''
# (0018,1510) Positioner Primary Angle            DS: '-32'
# (0018,1511) Positioner Secondary Angle          DS: '2'
# (0019,0010) Private Creator                     LO: 'CARDIO-D.R. 1.0'
# (0019,1030) [Maximum Frame Size]                UL: 262144
# (0020,000D) Study Instance UID                  UI: 1.3.12.2.1107.5.4.3.123456789012345.19950922.121803.6
# (0020,000E) Series Instance UID                 UI: 1.3.12.2.1107.5.4.3.123456789012345.19950922.121803.8
# (0020,0010) Study ID                            SH: ''
# (0020,0011) Series Number                       IS: '1'
# (0020,0013) Instance Number                     IS: None
# (0020,0020) Patient Orientation                 CS: ''
# (0021,0010) Private Creator                     LO: 'CARDIO-D.R. 1.0'
# (0021,1013) [Image Sequence Number]             IS: '15'
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0008) Number of Frames                    IS: '96'
# (0028,0009) Frame Increment Pointer             AT: (0018,1063)
# (0028,0010) Rows                                US: 512
# (0028,0011) Columns                             US: 512
# (0028,0100) Bits Allocated                      US: 8
# (0028,0101) Bits Stored                         US: 8
# (0028,0102) High Bit                            US: 7
# (0028,0103) Pixel Representation                US: 0
# (0028,1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028,1090) Recommended Viewing Mode            CS: 'NAT'
# (0028,6040) R Wave Pointer                      US: [20, 53, 77]
# (0028,6100)  Mask Subtraction Sequence  1 item(s) ----
#    (0028,6101) Mask Operation                      CS: 'NONE'
#    (0028,6110) Mask Frame Numbers                  US: 0
#    ---------
# (0029,0010) Private Creator                     LO: 'CARDIO-D.R. 1.0'
# (0029,1000)  Private tag data  1 item(s) ----
#    (0029,0010) Private Creator                     LO: 'CARDIO-D.R. 1.0'
#    (0029,1001) [Convolution Kernel Size]           US: [5, 5]
#    (0029,1002) [Convolution Kernel Coefficients]   US: Array of 25 elements
#    (0029,1003) [Edge Enhancement Gain]             FL: 0.5
#    ---------
# (5000,0005) Curve Dimensions                    US: 2
# (5000,0010) Number of Points                    US: 3840
# (5000,0020) Type of Data                        CS: 'ECG'
# (5000,0030) Axis Units                          SH: ['DPPS', 'NONE']
# (5000,0103) Data Value Representation           US: 0
# (5000,0104) Minimum Coordinate Value            US: None
# (5000,0105) Maximum Coordinate Value            US: None
# (5000,0106) Curve Range                         US: None
# (5000,0110) Curve Data Descriptor               US: [0, 1]
# (5000,0112) Coordinate Start Value              US: 0
# (5000,0114) Coordinate Step Value               US: 40
# (5000,3000) Curve Data                          OW: Array of 7680 elements
# (7FE0,0010) Pixel Data                          OB: Array of 1691664 elements

# %%
list_frames = []
for frame in dicom_instance3.pixel_array:
    modified_image_array = draw_text_on_image_opencv(frame, str(dicom_instance.PatientName), position, 1.0, font_color, thickness, font)
    position = (20, 140)
    modified_image_array = draw_text_on_image_opencv(modified_image_array, str(dicom_instance.PatientBirthDate), position, 1.0, font_color, thickness, font)
    list_frames.append(modified_image_array.tostring())
# Out:
# /tmp/ipykernel_27903/570796494.py:6: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   list_frames.append(modified_image_array.tostring())

# %%
list_frames = np.array(list_frames)

# %%
dicom_instance3.PixelData  = list_frames.tostring()
# Out:
# /tmp/ipykernel_27903/865813506.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   dicom_instance3.PixelData  = list_frames.tostring()

# %%
import numpy as np
import cv2

def visualize_array_as_video(array):
    # Create a VideoWriter object
    height, width = array.shape[1], array.shape[2]
    out = cv2.VideoWriter('output.avi', cv2.VideoWriter_fourcc(*'DIVX'), 15, (width, height), isColor=False)

    for i in range(array.shape[0]):
        frame = (array[i] * 255).astype(np.uint8)  # Convert to uint8
        out.write(frame)

    out.release()
    print("Video saved as output.avi")

# %%
#visualize_array_as_video(list_frames)

# %%
#dicom_instance3

# %%
# plt.figure(figsize=(10,10))
# plt.imshow(dicom_instance3.pixel_array[0])
