# %%
def mock_get_recommendations(badge_id, count=10):
    """Generate mock recommendations for testing when Neo4j is not available."""
    # Sample sessions for testing
    sessions = [
        {
            "session_id": "49823",
            "stream": "Debate",
            "title": "Preparing for Change: The CMA Investigation, where we are and possible implications for the profession",
            "end_time": "15:30:00",
            "synopsis_stripped": "No Data",
            "sponsored_by": "Not Sponsored",
            "start_time": "14:30:00",
            "sponsored_session": "False",
            "date": "2025-06-13",
            "theatre__name": "Business, Careers and Debates Theatre",
            "similarity": 0.935
        },
        {
            "session_id": "42156",
            "stream": "cattle",
            "title": "Managing Dairy Herd Health: Preventative Strategies",
            "end_time": "12:30:00",
            "synopsis_stripped": "Learn about the latest approaches to preventative medicine in dairy herds with a focus on reducing antimicrobial use.",
            "sponsored_by": "Not Sponsored",
            "start_time": "11:00:00",
            "sponsored_session": "False",
            "date": "2025-06-14",
            "theatre__name": "Clinical Theatre 2",
            "similarity": 0.884
        },
        {
            "session_id": "37891",
            "stream": "small animal;exotics",
            "title": "Exotic Pet Emergencies: First Response Protocols",
            "end_time": "16:45:00",
            "synopsis_stripped": "This session covers emergency care for common exotic pets, focusing on rapid assessment and stabilization.",
            "sponsored_by": "Not Sponsored",
            "start_time": "15:15:00",
            "sponsored_session": "False",
            "date": "2025-06-13",
            "theatre__name": "Clinical Theatre 1",
            "similarity": 0.812
        },
        {
            "session_id": "51472",
            "stream": "wellbeing;management",
            "title": "Veterinary Leadership: Building Resilient Teams",
            "end_time": "14:15:00",
            "synopsis_stripped": "Explore strategies for developing team resilience and effective leadership in veterinary practice.",
            "sponsored_by": "VetPartners",
            "start_time": "13:00:00",
            "sponsored_session": "True",
            "date": "2025-06-15",
            "theatre__name": "Business, Careers and Debates Theatre",
            "similarity": 0.799
        },
        {
            "session_id": "45238",
            "stream": "nursing",
            "title": "Advanced Monitoring Techniques for Veterinary Nurses",
            "end_time": "11:30:00",
            "synopsis_stripped": "This practical session demonstrates the latest monitoring techniques for critical care patients.",
            "sponsored_by": "Not Sponsored",
            "start_time": "10:00:00",
            "sponsored_session": "False",
            "date": "2025-06-14",
            "theatre__name": "Nursing Theatre",
            "similarity": 0.785
        },
        {
            "session_id": "46781",
            "stream": "equine",
            "title": "Equine Colic Management",
            "end_time": "16:00:00",
            "synopsis_stripped": "This session covers the latest in equine colic diagnosis and treatment options.",
            "sponsored_by": "Not Sponsored",
            "start_time": "14:30:00",
            "sponsored_session": "False",
            "date": "2025-06-14",
            "theatre__name": "Clinical Theatre 3",
            "similarity": 0.762
        },
        {
            "session_id": "39524",
            "stream": "farm;cattle",
            "title": "Sustainable Dairy Farming",
            "end_time": "11:45:00",
            "synopsis_stripped": "Exploring environmental management in dairy production.",
            "sponsored_by": "Not Sponsored",
            "start_time": "10:15:00",
            "sponsored_session": "False",
            "date": "2025-06-15",
            "theatre__name": "Clinical Theatre 2",
            "similarity": 0.741
        },
        {
            "session_id": "52183",
            "stream": "feline;small animal",
            "title": "Feline Geriatric Medicine",
            "end_time": "12:30:00",
            "synopsis_stripped": "Managing the health of senior cats.",
            "sponsored_by": "Hills",
            "start_time": "11:00:00",
            "sponsored_session": "True",
            "date": "2025-06-13",
            "theatre__name": "Clinical Theatre 1",
            "similarity": 0.723
        },
        {
            "session_id": "48612",
            "stream": "nursing;wellbeing",
            "title": "Stress Management for Veterinary Nurses",
            "end_time": "14:30:00",
            "synopsis_stripped": "Techniques for managing workplace stress.",
            "sponsored_by": "Not Sponsored",
            "start_time": "13:00:00",
            "sponsored_session": "False",
            "date": "2025-06-15",
            "theatre__name": "Nursing Theatre",
            "similarity": 0.704
        },
        {
            "session_id": "40357",
            "stream": "business",
            "title": "Digital Marketing for Veterinary Practices",
            "end_time": "15:45:00",
            "synopsis_stripped": "Effective online marketing strategies.",
            "sponsored_by": "VetPartners",
            "start_time": "14:15:00",
            "sponsored_session": "True",
            "date": "2025-06-14",
            "theatre__name": "Business, Careers and Debates Theatre",
            "similarity": 0.682
        }
    ]
    
    # Return a random subset of sessions for testing
    import random
    random.shuffle(sessions)
    return sessions[:min(count, len(sessions))]
