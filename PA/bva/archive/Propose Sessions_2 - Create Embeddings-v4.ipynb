# %%
# Import required libraries
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

uri = "bolt://127.0.0.1:7687"
username = "neo4j"
password = ""  # Replace with your password.

# Initialize Neo4j driver
driver = GraphDatabase.driver(uri, auth=(username, password))

# Load a good text embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")
model = SentenceTransformer(
    "nomic-ai/nomic-embed-text-v1", trust_remote_code=True
)  # , device="cuda")
# Out:
# <All keys matched successfully>

# %%
text = """Urology in veterinary medicine focuses on the diagnosis, treatment, and management of diseases and conditions affecting the urinary tract and kidneys in animals. 
This category encompasses a wide range of topics including proteinuria interpretation, urinary tract infections, obstructive conditions like blocked bladder, and surgical
interventions for urolithiasis. It also highlights the importance of diagnostic imaging techniques and the critical role of veterinary nurses in managing chronic kidney disease. 
Overall, urology integrates medical, surgical, and supportive care approaches to maintain and restore urinary health in various animal species."""
len(model.encode(text))
# Out:
# 768

# %%
# Default values for properties
default_properties = {
    "Days_since_registration": "119",
    "Country": "UK",
    "Source": "BVA Key Stakeholders",
    "Email_domain": "effem.com",
    "assist_year_before": "1",
    "job_role": "NA",
    "what_type_does_your_practice_specialise_in": "NA",
    "organisation_type": "NA",
    "JobTitle": "NA",
}


def set_default_properties(tx, properties):
    query = """
    MATCH (n:Visitor_this_year)
    SET
    """ + ",\n    ".join(
        [f"n.{key} = COALESCE(n.{key}, $props.{key})" for key in properties.keys()]
    )

    tx.run(query, props=properties)


def main():

    with driver.session() as session:
        session.execute_write(set_default_properties, default_properties)
    driver.close()
    print("Missing properties set to default values for all Visitor_this_year nodes.")

# %%
main()
# Out:
# Missing properties set to default values for all Visitor_this_year nodes.

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load a good text embedding model
model = SentenceTransformer("nomic-ai/nomic-embed-text-v1", trust_remote_code=True)

# Define job role categories
VET_ROLES = [
    "Vet/Vet Surgeon",
    "Assistant Vet",
    "Vet/Owner",
    "Clinical or other Director",
    "Locum Vet" "Academic",
]

NURSE_ROLES = ["Head Nurse/Senior Nurse", "Vet Nurse", "Locum RVN"]

BUSINESS = ["Practice Manager", "Practice Partner/Owner"]
# Other roles can attend any session
OTHER_ROLES = ["Student", "Receptionist", "Other (please specify)"]


# Define session embedding
def create_session_embedding(session, stream_descriptions=None):
    # Include title, synopsis_stripped, and theatre__name as required
    base_text = f"{session['title']} {session['synopsis_stripped']} {session['theatre__name']} {session['sponsored_by']}"

    # Add stream descriptions if provided
    if stream_descriptions and len(stream_descriptions) > 0:
        stream_desc_text = " ".join(stream_descriptions)
        text = f"{base_text} {stream_desc_text}"
    else:
        text = base_text

    return model.encode(text)


# Embedding function for all sessions
def embed_all_sessions(tx):
    # Query all Sessions from past_year_dva, past_year_lva, Sessions_past_year (for compatibility) and this_year
    # Include the new sponsored_by and sponsored_session attributes
    query = """
    MATCH (s)
    WHERE s:Sessions_past_year_dva OR s:Sessions_past_year_lva OR s:Sessions_this_year OR s:Sessions_past_year
    RETURN s.session_id as session_id, s.title as title, 
           s.stream as stream, s.synopsis_stripped as synopsis_stripped,
           s.theatre__name as theatre__name, s.sponsored_by as sponsored_by,
           s.sponsored_session as sponsored_session, labels(s)[0] as type,
           CASE WHEN s.key_text IS NOT NULL THEN s.key_text ELSE '' END as key_text
    """
    sessions = tx.run(query).data()

    # Fetch all stream descriptions once to avoid multiple queries
    stream_query = """
    MATCH (s:Stream)
    RETURN s.stream as stream, s.description as description
    """
    stream_data = tx.run(stream_query).data()

    # Create a dictionary of stream descriptions for quick lookup
    stream_descriptions = {s["stream"].lower(): s["description"] for s in stream_data}

    embeddings = {}
    for s in sessions:
        # Process the stream field - split by semicolon and handle duplicates
        session_streams = []
        if s["stream"]:
            # Split the stream string and strip whitespace
            stream_list = [stream.strip().lower() for stream in s["stream"].split(";")]
            # Remove duplicates by converting to set and back to list
            stream_list = list(set(stream_list))

            # Get the description for each stream
            for stream in stream_list:
                if stream in stream_descriptions:
                    session_streams.append(stream_descriptions[stream])

        # Create embedding with the session data and stream descriptions
        embeddings[s["session_id"]] = {
            "type": s["type"],
            "embedding": create_session_embedding(s, session_streams),
            "theatre__name": s["theatre__name"],
            "stream": s["stream"],
            "sponsored_by": (
                s["sponsored_by"] if "sponsored_by" in s else "Not Sponsored"
            ),
            "sponsored_session": (
                s["sponsored_session"] if "sponsored_session" in s else "False"
            ),
            "key_text": s["key_text"] if "key_text" in s else "",
        }

    return embeddings


# Visitor-based similarity
def visitor_similarity(v1, v2, attrs):
    vec1 = np.array([1 if v1[a] == v2[a] else 0 for a in attrs])
    return vec1.mean()


# Function to check if a session is appropriate for a visitor's job role
def is_session_appropriate_for_role(session_stream, job_role):
    # Rule 1: Vets and nurses – sessions are exclusive
    if not session_stream or not job_role:
        return True  # If we don't have stream or job role data, don't filter

    session_stream_lower = session_stream.lower()

    # Check if session is nurse-specific (contains nursing keywords)
    is_nurse_session = any(
        keyword in session_stream_lower
        for keyword in ["nurse", "nursing", "rvn", "veterinary nurse", "head nurse"]
    )

    # Check if session is vet-specific (contains vet keywords)
    is_vet_session = any(
        keyword in session_stream_lower
        for keyword in [
            "vet",
            "surgeon",
            "clinical",
            "veterinarian",
            "veterinary surgeon",
        ]
    )  # removed  'practice owner' Juan 23042025

    # Apply the rules
    if job_role in VET_ROLES:
        # Vets shouldn't get nurse-specific sessions
        if is_nurse_session and not is_vet_session:
            return False
    elif job_role in NURSE_ROLES:
        # Nurses shouldn't get vet-specific sessions
        if is_vet_session and not is_nurse_session:
            return False

    # For other roles or non-specific sessions, allow them
    return True


# Function to get Zoetis sponsored sessions
def get_zoetis_sessions(tx):
    """Get all sessions sponsored by Zoetis this year"""
    query = """
    MATCH (s:Sessions_this_year)
    WHERE s.sponsored_by = 'Zoetis'
    RETURN s.session_id as session_id
    """
    results = tx.run(query).data()
    return [r["session_id"] for r in results]


# Function to check if a visitor should receive Zoetis sponsored recommendations
def check_for_zoetis_recommendations(tx, similar_visitor_badge_ids):
    """
    Rule 3: When doing Visitor similarity if one of the similar visitors
    is node type "Visitor_last_year_lva" and this Visitor attend sessions
    sponsored by "Zoetis", recommend sessions from this sponsor
    """
    # Check if there are similar visitors
    if not similar_visitor_badge_ids:
        return []

    zoetis_sessions = []

    # For each similar visitor
    for similar_vid in similar_visitor_badge_ids:
        # Check if they're "Visitor_last_year_lva" and attended Zoetis sessions
        query = """
        MATCH (v:Visitor_this_year {BadgeId: $similar_vid})-[:Same_Visitor]->(vp:Visitor_last_year_lva)-[:attended_session]->(sp:Sessions_past_year)
        WHERE sp.sponsored_by = 'Zoetis'
        RETURN count(sp) > 0 as attended_zoetis
        """
        result = tx.run(query, similar_vid=similar_vid).single()
        if result and result["attended_zoetis"]:
            # Get Zoetis sessions for this year
            zoetis_sessions.extend(get_zoetis_sessions(tx))
            break  # Found at least one qualifying visitor

    # Return unique list of Zoetis session IDs
    return list(set(zoetis_sessions))


# Modified recommend_sessions function to return session IDs with similarity scores
def recommend_sessions(tx, visitor_id, session_embeddings):
    # First check if visitor exists and get their info
    visitor_query = """
    MATCH (v:Visitor_this_year {BadgeId: $visitor_id})
    RETURN v
    """
    visitor_data = tx.run(visitor_query, visitor_id=visitor_id).single()
    if not visitor_data:
        return []
    visitor = visitor_data["v"]
    assisted = visitor["assist_year_before"]
    job_role = visitor.get("job_role", "")  # Get job role for Rule 1

    # Check if visitor is a surgeon for Rule 2
    is_surgeon = False
    if job_role:
        # Check if job_role contains surgeon or is a clinical director
        is_surgeon = (
            "surgeon" in job_role.lower() or job_role == "Vet/Vet Surgeon"
        )  # removed or job_role == 'Clinical or other Director' Juan 23042025

    recommendations = []
    similar_visitor_badge_ids = []

    if assisted == "1":
        # Case 1: Visitor attended last year
        query_past = """
        MATCH (v:Visitor_this_year {BadgeId: $visitor_id})-[:Same_Visitor]->(vp_bva:Visitor_last_year_bva)-[:attended_session]->(sp_bva:Sessions_past_year)
        RETURN sp_bva.session_id as session_id
        UNION
        MATCH (v:Visitor_this_year {BadgeId: $visitor_id})-[:Same_Visitor]->(vp_lva:Visitor_last_year_lva)-[:attended_session]->(sp_lva:Sessions_past_year)
        RETURN sp_lva.session_id as session_id
        """
        past_sessions = tx.run(query_past, visitor_id=visitor_id).data()

        # Get all sessions for this year
        this_year_sessions = {
            k: v
            for k, v in session_embeddings.items()
            if v["type"] == "Sessions_this_year"
        }

        # For surgeons, first add relevant "Referrals & Diagnostics Theatre" sessions
        if is_surgeon:
            surgeon_sessions = []
            for sid, data in this_year_sessions.items():
                if data["theatre__name"] == "Referrals & Diagnostics Theatre":
                    # Verify it's appropriate for the role
                    if is_session_appropriate_for_role(data["stream"], job_role):
                        # Add with similarity score of 1.0 (highest) for surgeon-specific recommendations
                        surgeon_sessions.append(
                            {
                                "session_id": sid,
                                "similarity": 1.0,
                                "reason": "Surgeon-specific",
                            }
                        )

            # Add top 2 surgeon-specific sessions # remove the limit . add all surgeon specific Juan 23042025
            recommendations.extend(surgeon_sessions)  # surgeon_sessions[:2]

        # Process previously attended sessions
        for past_sess in past_sessions:
            # Check if the session_id exists in embeddings
            if past_sess["session_id"] not in session_embeddings:
                continue  # Skip this session if it's not in our embeddings

            past_emb = session_embeddings[past_sess["session_id"]]["embedding"]
            past_session_id = past_sess["session_id"]

            similarities = []
            for sid, data in this_year_sessions.items():
                # Skip if we've already recommended this session
                if any(r["session_id"] == sid for r in recommendations):
                    continue

                # Apply Rule 1: Check if session is appropriate for job role
                if not is_session_appropriate_for_role(data["stream"], job_role):
                    continue

                sim = cosine_similarity([past_emb], [data["embedding"]])[0][0]

                # Apply Rule 2: If surgeon, boost "Referrals & Diagnostics Theatre" sessions
                reason = f"Similar to previously attended session"
                if (
                    is_surgeon
                    and data["theatre__name"] == "Referrals & Diagnostics Theatre"
                ):
                    sim += 0.2  # Boost by 0.2
                    reason += " (boosted for surgeon)"

                similarities.append(
                    {"session_id": sid, "similarity": sim, "reason": reason}
                )

            # Sort by similarity and pick top similar ones
            similarities.sort(key=lambda x: -x["similarity"])
            recommendations.extend(
                similarities
            )  # remove the limit . add all similar specific Juan 23042025 similarities[:2]

    else:
        # Case 2: New visitor - find similar visitors with history
        visitor_attrs = [
            "Days_since_registration",
            "Country",
            "Source",
            "Email_domain",
            "JobTitle",
            "assist_year_before",
            "job_role",
            "what_type_does_your_practice_specialise_in",
            "organisation_type",
        ]

        all_visitors = tx.run(
            """
            MATCH (v:Visitor_this_year)
            WHERE v.assist_year_before = '1'
            RETURN v
        """
        ).data()

        similarities = []
        for vdata in all_visitors:
            v_compare = vdata["v"]
            sim = visitor_similarity(visitor, v_compare, visitor_attrs)
            similarities.append((v_compare["BadgeId"], sim))

        similarities.sort(key=lambda x: -x[1])
        similar_visitor_badge_ids = [
            sid for sid, _ in similarities[:3]
        ]  # USe 3 similar visitors Juan 23042025

        # Get all sessions for this year
        this_year_sessions = {
            k: v
            for k, v in session_embeddings.items()
            if v["type"] == "Sessions_this_year"
        }

        # For surgeons, first add relevant "Referrals & Diagnostics Theatre" sessions
        if is_surgeon:
            surgeon_sessions = []
            for sid, data in this_year_sessions.items():
                if data["theatre__name"] == "Referrals & Diagnostics Theatre":
                    # Verify it's appropriate for the role
                    if is_session_appropriate_for_role(data["stream"], job_role):
                        # Add with similarity score of 1.0 (highest) for surgeon-specific recommendations
                        surgeon_sessions.append(
                            {
                                "session_id": sid,
                                "similarity": 1.0,
                                "reason": "Surgeon-specific",
                            }
                        )

            # Add top 2 surgeon-specific sessions
            recommendations.extend(
                surgeon_sessions
            )  # # remove the limit . add all surgeon specific Juan 23042025 surgeon_sessions[:2]

        # Rule 3: Check for Zoetis recommendations if similar visitors are last_year_lva
        # and attended Zoetis-sponsored sessions
        zoetis_sessions = check_for_zoetis_recommendations(
            tx, similar_visitor_badge_ids
        )

        # Filter Zoetis sessions to ensure they match job role requirements
        filtered_zoetis = []
        for zsid in zoetis_sessions:
            if zsid in this_year_sessions:
                # Apply Rule 1: Check if session is appropriate for job role
                if is_session_appropriate_for_role(
                    this_year_sessions[zsid]["stream"], job_role
                ):
                    # Add with similarity score of 0.9 (high) for sponsor-specific recommendations
                    filtered_zoetis.append(
                        {
                            "session_id": zsid,
                            "similarity": 0.9,
                            "reason": "Zoetis sponsored",
                        }
                    )

        # Add up to 2 Zoetis sessions
        recommendations.extend(filtered_zoetis[:2])

        # Process sessions from similar visitors
        for similar_vid in similar_visitor_badge_ids:
            query_sim_past = """
                MATCH (v:Visitor_this_year {BadgeId: $similar_vid})-[:Same_Visitor]->(vp)-[:attended_session]->(sp:Sessions_past_year)
                WHERE vp:Visitor_last_year_bva OR vp:Visitor_last_year_lva
                RETURN sp.session_id AS session_id,
                       CASE WHEN vp:Visitor_last_year_lva THEN true ELSE false END as is_lva
            """
            user_past_sessions = tx.run(query_sim_past, similar_vid=similar_vid).data()

            for past_sess in user_past_sessions:
                # Check if the session_id exists in embeddings
                if past_sess["session_id"] not in session_embeddings:
                    continue  # Skip this session if it's not in our embeddings

                past_emb = session_embeddings[past_sess["session_id"]]["embedding"]

                similarities = []
                for sid, data in this_year_sessions.items():
                    # Skip if we've already recommended this session
                    if any(r["session_id"] == sid for r in recommendations):
                        continue

                    # Apply Rule 1: Check if session is appropriate for job role
                    if not is_session_appropriate_for_role(data["stream"], job_role):
                        continue

                    sim = cosine_similarity([past_emb], [data["embedding"]])[0][0]
                    reason = f"Similar to session attended by similar visitor"

                    # Apply Rule 2: If surgeon, boost "Referrals & Diagnostics Theatre" sessions
                    if (
                        is_surgeon
                        and data["theatre__name"] == "Referrals & Diagnostics Theatre"
                    ):
                        sim += 0.2  # Boost by 0.2
                        reason += " (boosted for surgeon)"

                    similarities.append(
                        {"session_id": sid, "similarity": sim, "reason": reason}
                    )

                # Sort by similarity and pick top similar ones
                similarities.sort(key=lambda x: -x["similarity"])
                recommendations.extend(
                    similarities
                )  # remove the limit . add all similar specific Juan 23042025 similarities[:2]

    # Remove duplicates (keeping the first occurrence with its similarity score)
    seen = set()
    unique_recommendations = []
    for rec in recommendations:
        if rec["session_id"] not in seen:
            seen.add(rec["session_id"])
            unique_recommendations.append(rec)

    # Return top 10 recommendations with their similarity scores
    return unique_recommendations  # remove the limit . add all recommendations Juan 23042025 unique_recommendations[:10]


# Modified function to filter sessions with similarity scores
def filter_sessions_by_visitor_stream_relationships(
    tx, visitor_id, session_recommendations
):
    """
    Filter sessions to keep only those where the visitor has a relationship
    (specialization_to_stream or job_to_stream) to any Stream that has a HAS_STREAM
    relationship to the session. Preserves similarity scores.
    """
    if not session_recommendations:
        return []

    # Extract just the session IDs for the query
    session_ids = [rec["session_id"] for rec in session_recommendations]

    # Query to find sessions with valid stream relationships to the visitor
    query = """
    MATCH (v:Visitor_this_year {BadgeId: $visitor_id})
    MATCH (s:Sessions_this_year)
    WHERE s.session_id IN $session_ids
    MATCH (s)-[:HAS_STREAM]->(stream:Stream)<-[r]-(v)
    WHERE type(r) IN ['specialization_to_stream', 'job_to_stream']
    RETURN DISTINCT s.session_id as session_id
    """

    results = tx.run(query, visitor_id=visitor_id, session_ids=session_ids).data()
    valid_session_ids = set(r["session_id"] for r in results)

    # Filter the original recommendations to keep only valid sessions with their scores
    filtered_recommendations = [
        rec for rec in session_recommendations if rec["session_id"] in valid_session_ids
    ]

    return filtered_recommendations


# Modified get_session_attributes to include similarity scores
def get_session_attributes(session_recommendations):
    # Handle empty recommendations to prevent errors
    if not session_recommendations:
        return []

    # Extract just the session IDs for the query
    session_ids = [rec["session_id"] for rec in session_recommendations]

    # Create a mapping of session_id to similarity score for later use
    similarity_map = {
        rec["session_id"]: {"similarity": rec["similarity"], "reason": rec["reason"]}
        for rec in session_recommendations
    }

    query = """
    MATCH (s:Sessions_this_year)
    WHERE s.session_id IN $session_ids
    RETURN s {
        .stream,
        .session_id,
        .title,
        .synopsis_stripped,
        .end_time,
        .start_time,
        .date,
        .theatre__name,
        .sponsored_by,
        .sponsored_session
    } AS session_details
    """

    with driver.session() as session:
        results = session.run(query, session_ids=session_ids)
        session_details = []

        for record in results:
            details = record["session_details"]
            # Add similarity score and reason to the session details
            session_id = details["session_id"]
            if session_id in similarity_map:
                details["similarity_score"] = similarity_map[session_id]["similarity"]
                details["recommendation_reason"] = similarity_map[session_id]["reason"]
            session_details.append(details)

    # Sort by similarity score (highest first)
    session_details.sort(key=lambda x: x.get("similarity_score", 0), reverse=True)

    return session_details


# Cached embeddings at the module level
_session_embeddings = None


def get_recommendations(visitor_id):
    """
    Main function to get recommendations for a visitor.
    Returns full session details for recommended sessions, including similarity scores.
    """
    global _session_embeddings

    # Create session embeddings once if they don't exist
    if _session_embeddings is None:
        with driver.session() as session:
            _session_embeddings = session.execute_read(embed_all_sessions)

    # Use the cached embeddings for recommendations
    with driver.session() as session:
        # Get initial recommended sessions with similarity scores
        recommended_sessions = session.execute_read(
            recommend_sessions,
            visitor_id=visitor_id,
            session_embeddings=_session_embeddings,
        )

        # Apply the additional filter for stream relationships
        filtered_sessions = session.execute_read(
            filter_sessions_by_visitor_stream_relationships,
            visitor_id=visitor_id,
            session_recommendations=recommended_sessions,
        )

    # Get the details of the filtered recommended sessions with similarity scores
    recommended_sessions_details = get_session_attributes(filtered_sessions)

    return recommended_sessions_details


# Example usage:
# recommended_sessions = get_recommendations("MV4H3PQ")
# Out:
# C:\Users\HYSTOU\.cache\huggingface\modules\transformers_modules\nomic-ai\nomic-bert-2048\e5042dce39060cc34bc223455f25cf1d26db4655\modeling_hf_nomic_bert.py:116: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = loader(resolved_archive_file)
# <All keys matched successfully>

# %%
# Example usage:
visitor_id_example = "MV4H3PQ"  #  No visit last year
driver = GraphDatabase.driver(uri, auth=(username, password))
recommended_sessions = get_recommendations(visitor_id_example)

# %%
for session in recommended_sessions:
    print(session)
    print("*" * 25)
# Out:
# {'session_id': '49679', 'stream': 'Ophthalmology; Small Animal', 'title': 'What to look for - common ocular conditions on Brachycephalics', 'end_time': '12:00:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:10:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.83763087, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49684', 'stream': 'Behaviour; Small Animal', 'title': 'Handle with care: Fundamentals of behavioural first aid in general practice', 'end_time': '10:20:00', 'synopsis_stripped': "General practices are uniquely positioned to play a central role in the lifelong emotional health of companion animals - we are able to proactively ask owners about their pets’ behaviour, give preventative advice, and provide early interventions if problems arise. Unfortunately, many owners delay seeking veterinary help for their pet's behaviour until the problem is severe. Veterinarians can often feel poorly prepared to manage these challenging cases, especially within the time available in first\xa0opinion practice, and unsure of what advice to give. Behaviour first aid provides a flexible, practical framework for the first response to any behaviour problem. There is always something you can do to help, and a first aid approach helps pets and owners when they need it most. Learn how to take an effective behaviour history, investigate medical comorbidities, mitigate risk, and give actionable advice to optimise welfare and prevent the problem from getting worse.\xa0", 'sponsored_by': 'Forte Healthcare Ltd', 'start_time': '09:30:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.7382635, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49685', 'stream': 'Emergency Medicine; Small Animal', 'title': 'Take your own pulse first: CPR and how to survive running a crash.', 'end_time': '11:25:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.7312846, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49676', 'stream': 'Emergency Medicine; Emergency Medicine; Small Animal; Small Animal', 'title': 'Stay or go? Discharge decisions for emergency cases?', 'end_time': '17:40:00', 'synopsis_stripped': 'Not every small animal emergency case requires hospitalisation, however determining which patients can be managed safely as outpatients can be challenging. When can a patient be safely managed at home? When is hospitalisation essential and when is homecare reasonable? This session will explore a practical approach to making admission decisions for common emergencies, including seizure patients, trauma cases, blocked cats, and those with haemorrhagic diarrhoea. We’ll then discuss a practical framework to balance clinical needs with pet-owner preferences and other considerations, with advice on setting realistic expectations and monitoring.', 'sponsored_by': 'Not Sponsored', 'start_time': '16:50:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.72332436, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49801', 'stream': 'Equine; Large Animal', 'title': 'Risk communication in the horse with colic: getting the best outcomes and preventing recurrence.', 'end_time': '14:20:00', 'synopsis_stripped': 'Colic is one of the most frequent reasons for emergency equine veterinary consultations in first opinion practice, with around 25% of cases requiring hospital admission. It is a major healthcare concern for horse owners and is one of the most common causes of equine morbidity and mortality. As veterinary professionals, it is important that we can use available evidence to inform owners about colic prevention and management, including the potential need for surgical intervention and likely outcomes following surgery. \xa0It is also important to use this information when making evidence-based decisions around veterinary care of the horse with colic. This lecture will cover the following: Common myths and challenges around communicating colic risk with horse owners; Identifying and managing the at-risk horse; Evidence-based approaches to veterinary diagnosis and management; Surgical outcomes based on the findings of the International Colic Surgery Audit (INCISE); Surgical procedures to reduce colic recurrence.', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.720765, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49803', 'stream': 'Equine; Large Animal', 'title': 'How to manage major trauma events', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.71268284, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49802', 'stream': 'Equine; Large Animal', 'title': 'Where do we start with recurrent colic: What is likely and how do I treat it?', 'end_time': '15:25:00', 'synopsis_stripped': 'The session will detail how to investigate recurrent colic, detailing how to use physical examination, endoscopy, abdominal ultrasound and clinical pathology in formulating a presumptive diagnosis. Treatment and management options will be covered. The session will be case based fostering an understanding of what causes recurrent abdominal pain, how it changes and the interplay between aetiology, clinical presentation, diagnostic imaging and treatment response.', 'sponsored_by': 'Not Sponsored', 'start_time': '14:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.7118011, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49810', 'stream': 'Farm; Large Animal', 'title': "Don't be allama'd! Triaging the emergency camelid case", 'end_time': '15:05:00', 'synopsis_stripped': 'Don’t Panic!\n\xa0\nAs the UK camelid population grows, there is an increasing demand for large animal practitioners to tend to alpaca and llama patients. A lack of understanding of their physiology and clinical quirks due to (until recently) little undergraduate teaching on the subject, can render novel or emergency camelid calls stressful. But don’t panic – you have many skills that are easily transferrable to camelids, and coupled with a little bit of nuanced knowledge, they can help you triage and treat emergency cases.\n\xa0\nBridge Knowledge Gaps\nPractices may be reluctant to take on a novel species, particularly one that can suffer from accelerated disease processes, carrying emotional and commercial value as both companions and commercial stock. In the author’s experience of working with camelids, it is evident that most owners wish to pursue diagnostics and embark upon schemes and practices that benefit their herd, which could be welcome news to vets already offering such services to different species. With insight from experienced production animal veterinarians, there is potential to reduce communicable disease transmission among other farmed species. It is therefore in all our interest that camelid owners are informed on matters of disease risk reduction and biosecurity – to do this, we must, as production vets, make efforts to extend clinical services in the hope of having these important discussions.\n\xa0\nSession Outline\nThis session aims to arm cattle practitioners with the skills required to undertake clinical examination and determine differential diagnoses for common, emergent camelid presentations. Emphasis will be put on breaking down camelid triage, and giving you east steps to provide first opinion care. It will identify differential diagnoses for common emergency presentations (with indicators of urgency) as well as identification of treatment pathways that are directly comparable to the more familiar species. Avenues for diagnostics will be discussed (as certain laboratory tests for common diseases can differ), and a camelid calendar will outline key times of year for risk periods.', 'sponsored_by': 'Bachelor of Veterinary Science', 'start_time': '14:25:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.7090983, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49687', 'stream': 'Small Animal; Surgery', 'title': 'Blood, sweat & tears - how to avoid them in theatre', 'end_time': '14:20:00', 'synopsis_stripped': 'Patients haemorrhaging can be stressful during surgery and anaesthesia. This lecture focuses on how to prevent intra-operative and post-operative haemorrhage by identifying and managing risk factors and will include recognition and management of the physiological and clinical consequences of haemorrhage. \xa0A case-based approach will be used to discuss perioperative stabilisation and a variety of haemostasis techniques and practical tips for the general practitioner.', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.70599204, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49804', 'stream': 'Equine; Large Animal', 'title': 'Did someone call the vet? How to get teams of people to thrive under pressure.', 'end_time': '17:35:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '16:45:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6989263, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49811', 'stream': 'Farm; Large Animal', 'title': 'Introduction to deer vetting', 'end_time': '16:00:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Veterinary Dental Association', 'start_time': '15:20:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.69244075, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49800', 'stream': 'Equine; Large Animal', 'title': 'Point of care ultrasound: when will it help me?', 'end_time': '12:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.690272, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49693', 'stream': 'Orthopaedics; Orthopaedics; Orthopaedics; Small Animal; Small Animal; Small Animal', 'title': 'Solving the lame dog… one step at a time', 'end_time': '12:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:55:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6850325, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49674', 'stream': 'Anaesthesia; Small Animal', 'title': 'Anaesthesia check lists: Do they protect our feline patients under GA?', 'end_time': '15:05:00', 'synopsis_stripped': 'This session will look at the history of anaesthesia check lists in both human and veterinary care. It will explore the evidence base around both their current utilisation and value, with the goal of understanding if they have a valuable role in protecting our feline patients.\xa0', 'sponsored_by': 'Not Sponsored', 'start_time': '14:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6837248, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49812', 'stream': 'Large Animal', 'title': 'Vets at the frontier of new and emerging diseases', 'end_time': '16:55:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Department for Environment, Food & Rural Affairs', 'start_time': '16:15:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6830474, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49697', 'stream': 'Equine; Large Animal', 'title': 'Neck pain in the horse, how do I spot it and what can I do next?', 'end_time': '10:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6820704, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49805', 'stream': 'Farm; Large Animal', 'title': "How to deal with small holder's and their sheep? Common issues and solutions!", 'end_time': '13:10:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Sheep Veterinary Society SVS', 'start_time': '12:30:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.68065715, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49682', 'stream': 'Oncology; Small Animal', 'title': 'The quest for comfort with cancer pain', 'end_time': '15:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '14:55:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6789262, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49691', 'stream': 'Neurology; Small Animal', 'title': 'Neurology - a video tour of seizures and their mimics', 'end_time': '10:35:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:45:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.67851365, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49690', 'stream': 'Feline; Small Animal', 'title': "Cat friendly interactions - avoiding 'cat' astrophes at the clinic", 'end_time': '17:35:00', 'synopsis_stripped': 'In this session we will explore the species-specific and individual needs of cats, and how these can influence their emotional state and behaviour at the veterinary clinic. We will look at what cat-friendly interactions are and the current evidence and resources available for veterinary professionals on this topic. We will discuss how applying cat-friendly techniques in the consult room aids with examinations and procedures and can help improve clinical outcomes of feline patients, whilst keeping the veterinary team safe and building trust with caregivers. Each cat and situation are different, so we will be thinking creatively and practically while examining some case-studies of how to troubleshoot and manage individual cats that are emotionally challenged when presented in the consulting room.', 'sponsored_by': 'Not Sponsored', 'start_time': '16:45:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6754823, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49698', 'stream': 'Equine; Large Animal', 'title': 'Wearable technology in the equine world: What works and how can I help my clients to use it?', 'end_time': '11:25:00', 'synopsis_stripped': 'Wearable technology use is growing in the equine world, and many owners have started using portable monitors to improve their horse’s welfare but also track their horse’s fitness journey. Unfortunately, the majority of these have not undergone scientific validation and therefore the data collected can be misleading in making decision about the horse’s fitness parameters. It is crucial to critically review validation data available for these devices prior to recommending or advising on their use, especially heart rate monitors and accelerometers as reliance on inaccurate data may be detrimental to the horse. However, validated monitors have an important role in the improvement of fitness programs tailored to each individual and in the prevention of catastrophic injuries in the sport horse, making them extremely valuable when interpreted appropriately. Helping clients understand the use and the limitations of these devices in assessing fitness is key to help optimizing training progress. The prophylactic properties of heart rate and accelerometers data should be integrated in the equine performance world, by helping prolong horses’ athletic careers but also from the welfare implications regarding safe animal use in sport disciplines. ', 'sponsored_by': 'Not Sponsored', 'start_time': '10:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6746761, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49807', 'stream': 'Farm; Large Animal', 'title': 'A toolkit for the pig visit', 'end_time': '12:15:00', 'synopsis_stripped': 'In this session, Gemma Thwaites and Pete Siviter will be providing an overview of husbandry, management and veterinary interventions in small scale pig herds. When faced with a pig visit, especially as a vet who does not specialise in this species, the difficulties surrounding handling and restraint can pose real problems so we will be giving advice on how physically to go about this in order to make the visit smoother and to manage your own (and clients’!) expectations. The second half of the session will be a ‘Question and Answer’, where we will take questions from the floor about common situations and how to deal with them – most particularly the methods available for euthanasia. Further resources and where to turn for help will be included as part of the session.', 'sponsored_by': 'Pig Veterinary Society', 'start_time': '11:35:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6738951, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49808', 'stream': 'Farm; Large Animal', 'title': "Treating pet dinosaurs: 3R's approach to preventative pet poultry medicine", 'end_time': '10:25:00', 'synopsis_stripped': 'What medications are most commonly used in pet hens and why? Are there alternative therapies or management options available to reduce, refine and replace antimicrobials in the most common presentations of pet hens?', 'sponsored_by': 'British Veterinary Poultry Association', 'start_time': '09:45:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.67267317, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49806', 'stream': 'Farm; Large Animal', 'title': 'Small farm and small holding cattle fertility', 'end_time': '11:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Bristol Commercial Valuers and Auctioneers', 'start_time': '10:40:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6709426, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49671', 'stream': 'Dermatology; Small Animal', 'title': 'Itchy, scratchy cats: Where to start, when to use preds?', 'end_time': '11:05:00', 'synopsis_stripped': 'This session will discuss the various different clinical presentations seen in allergic cats. The approach to the pruritic cat will be discussed in detail and finally the treatment options available for managing cats wit feline atopic skin syndrome', 'sponsored_by': 'Not Sponsored', 'start_time': '10:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6643754, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49683', 'stream': 'Internal Medicine; Internal Medicine', 'title': 'Canine liver disease: the latest recommendations', 'end_time': '16:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '16:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.66284704, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49688', 'stream': 'Small Animal; Toxicology', 'title': 'Veterinary toxicology - past, present and future?', 'end_time': '15:25:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Small Animal Veterinary Association', 'start_time': '14:35:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.66166437, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49678', 'stream': 'Cardiology; Small Animal', 'title': 'I heard a murmur: determining the significance of heart murmurs in cats', 'end_time': '10:55:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:05:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.660552, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49692', 'stream': 'Internal Medicine', 'title': 'The diagnosis of liver disease', 'end_time': '11:40:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:50:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6558053, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49686', 'stream': 'Dentistry; Small Animal', 'title': 'We don’t have (dental) x-ray vision - interactive case-based small animal dentistry', 'end_time': '12:30:00', 'synopsis_stripped': 'Don’t have dental radiography in your small animal setting and wondering if you should take the plunge?Or do you have all the gear but you’re struggling to get good radiographs and interpret them?Then this session is for you!Using real cases, this session will explain the importance of dental radiographs, give tips on optimising your images, and guide you through what to do with your images when you have them.', 'sponsored_by': 'Not Sponsored', 'start_time': '11:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6556217, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49696', 'stream': 'Geriatric Medicine; Small Animal', 'title': 'Paws and peace - navigating end of life care for pets', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Small Animal Veterinary Association', 'start_time': '15:40:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6514561, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49675', 'stream': 'Gastroenterology; Small Animal', 'title': 'Do cats get IMHA? (Immune-mediated diseases and their treatment in cats)', 'end_time': '16:25:00', 'synopsis_stripped': 'This talk will be a case-based discussion of IMHA in cats. As part of the discussion of IMHA treatment, we will also consider other immune-mediated diseases in cats and their management.', 'sponsored_by': 'Not Sponsored', 'start_time': '15:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.65126646, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49680', 'stream': 'Obesity; Small Animal', 'title': 'Dealing with the clinical and functional consequences of obesity in dogs and cats', 'end_time': '13:05:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '12:15:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6505234, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '52369', 'stream': 'Career Development', 'title': 'The cost of adverse events: How small steps can prevent big mistakes', 'end_time': '13:00:00', 'synopsis_stripped': 'In the complex world of veterinary practice, things don’t always go as we plan or intend, despite the greatest effort and care. But what are the hidden costs of these events for all involved? And how could they become valuable opportunities to learn and improve?\nSupporting colleagues when things don’t go as we intend and cultivating a culture of continuous improvement that avoids blame and judgement is essential to developing thriving teams and businesses. \nDuring this session, our panel discussion will explore a human factors approach to reframing adverse events as opportunities for learning and improvement and the benefits this can have for all involved. Whatever your role in practice, unlock tools and perspectives that not only give you a greater awareness of how your practice is performing, but enable you to take real steps in driving meaningful improvement whilst cultivating a supportive learning culture.\xa0', 'sponsored_by': 'Not Sponsored', 'start_time': '12:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.6480659, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49695', 'stream': 'Exotic Animal; Exotic Animal', 'title': 'Antibiotic use in exotics - not just a baytril deficiency!', 'end_time': '15:25:00', 'synopsis_stripped': "The World Health Organisation states: Antimicrobial resistance (AMR) is one of the top global public health and development threats. It is estimated that bacterial AMR was directly responsible for 1.27 million global deaths in 2019 and contributed to 4.95 million deaths. As veterinary professionals we are responsible for our prescribing behaviour when it comes to antimicrobials. Our drug choices should be considered and the use of second or third line antibiotics justified. Drug selection is mutlifactorial and when it comes to exotics many vets will reach for 'Baytril' in exotic animals because it is licensed, it is considered a 'safe' drug in exotic species, it can be effective, and knowledge may be lacking of 'safe' alternatives nevermind the doses. Unfortunately, many of the infections in exotics we see are often secondary to stress induced immunocompromise resulting in normal microflora becoming opportunistic pathogens. Without correcting the underlying issue then at best we will achieve control not cure, leading to yet more antibiotics being prescribed.Antibiotic selection in exotics (mamamls,birds, reptiles) is a massive topic to cover in one session, so come join me for a whirlwind tour of drug selection, pain assessment, and husbandry considerations that will reduce the stress of the individual animal, promoting immunocompetance, and empower you to make logical drug choices of first line antibtiotics and know when it is appropriate to reach for the fluoroquinolones.", 'sponsored_by': 'Not Sponsored', 'start_time': '14:35:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6458513, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49689', 'stream': 'Parasitology; Small Animal', 'title': 'Responsible prescribing of parasiticides: How and why dog & cat parasite prevention needs to change', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.64396346, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49677', 'stream': 'Reproduction; Small Animal', 'title': 'Canine neutering in context: Who? When? Why?', 'end_time': '09:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6438154, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49694', 'stream': 'Respiratory; Small Animal', 'title': 'Why, when and how of BOAS assessment', 'end_time': '14:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6354505, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49670', 'stream': 'Endocrinology', 'title': 'Managing diabetes in 2025! 104 years after the first diabetic dog received insulin!', 'end_time': '09:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6330641, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49681', 'stream': 'Gastroenterology', 'title': 'Scoop that poop: problem solving diarrhoea and constipation in cats', 'end_time': '14:40:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '13:50:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.62835586, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49809', 'stream': 'Farm; Large Animal', 'title': 'Catastrophic diseases of Honeybees…..the foulbroods', 'end_time': '14:10:00', 'synopsis_stripped': 'The two diseases , American Foulbrood and European Foulbrood, are very serious , potentially fatal bacterial diseases of honeybee colonies. They are called foulbrood because they affect the developing larvae which, when they die, produce a foul smelling odour. The diseases are global and have been known since ancient times. Aristotle described the conditions in his lifetime. American Foulbrood is caused by a rod shaped bacterium, Paenibacillus larvae, which exists in a spore form and a vegetative form. European Foulbrood is a bacterium, Melissococcus plutonius which does not sporulate. The pathogenesis of these infections are quite different and if left will destroy the colony. They are highly infectious and can easily spread with the behaviour of bees and the actions of beekeepers. Most European countries have these diseases classed as notifiable with the legal requirement that if suspected, it must be reported to the authorities for examination by a bee inspector. If a positive diagnosis is made, then mandatory destruction of the colony, with euthanasia and burning is required for AFB. EFB diagnosis will usually require euthanasia and burning but in some cases, shook swarm procedure or antibiotics can be utilized. Apiaries are placed on standstill until two clear inspections have occurred. Countries with a stringent bee inspection system have lower incidence, but because these bacteria are ubiquitous, it is unlikely that eradication can be achieved.', 'sponsored_by': 'British Bee Veterinary Association', 'start_time': '13:25:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.62746537, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '52371', 'stream': 'Debate', 'title': 'HOT TOPIC: Shaping the future: reforming the veterinary surgeons act and its impact', 'end_time': '11:25:00', 'synopsis_stripped': 'As the veterinary profession evolves, so must the framework that regulates it. Join experts from key organisations across the profession including the RCVS, BVNA, BVA and Vet Schools Council for a thought-provoking panel discussion on the future of the Veterinary Surgeons Act 1966 reform.\n\xa0\nListen to experts explore how the process for reforming the Veterinary Surgeons Act would take place. Learn about the challenges facing the profession, and the potential areas for change through reform. Understand the impact and benefit these changes could have for veterinary practices and the wider profession, including what this means for animal welfare, professional standards, and the future of the industry. Gain valuable insights, ask your questions, and be part of the conversation shaping the future of veterinary profession.', 'sponsored_by': 'Not Sponsored', 'start_time': '10:25:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.62716407, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49672', 'stream': 'Exotic Animal', 'title': 'It’s a knock out: Tips and tricks for successful small mammal anaesthesia', 'end_time': '12:35:00', 'synopsis_stripped': 'This talk will give an overview of how to prepare yourself (and your small mammal patient) for the ideal anaesthesia. Pre-operative, intra-operative and post-operative considerations will be discuss with species specific differences highlighted throughout.', 'sponsored_by': 'British Veterinary Zoological Society', 'start_time': '11:45:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.62526786, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49823', 'stream': 'Debate', 'title': 'Preparing for Change: The CMA Investigation, where we are and possible implications for the profession', 'end_time': '15:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '14:30:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5962802, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49817', 'stream': 'Debate', 'title': 'Where is the UK on bTB control?', 'end_time': '16:15:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5685769, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '49824', 'stream': 'Career Development', 'title': 'I’m so scared to make a mistake as I know I’ll get blamed', 'end_time': '16:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:45:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5428395, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************
# {'session_id': '53727', 'stream': 'Leadership', 'title': 'Leadership: why knowing yourself as a leader matters', 'end_time': '15:00:00', 'synopsis_stripped': 'This session will explore the crucial role self-awareness plays in effective leadership. Panellists will emphasise the role of understanding one’s strengths, weaknesses, values, and emotional triggers and how those allow leaders to make more informed decisions, build stronger teams, and foster a positive organisational culture. The session will delve into how self-reflection, emotional intelligence, and an authentic leadership style can improve communication, collaboration, and conflict resolution. The panel will also highlight the impact of self-awareness on leadership adaptability, empowering leaders to navigate change and manage diverse challenges. By knowing themselves, leaders can inspire trust and motivate others, creating an environment of growth and innovation', 'sponsored_by': 'Not Sponsored', 'start_time': '14:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.51804805, 'recommendation_reason': 'Similar to session attended by similar visitor'}
# *************************

# %%
# for session in recommended_sessions:
#     print(session)
#     print("*"*25)

# %%
# BRKLA7T Visit last year

visitor_id_example = "Z642DJP"  # Visitor_this_year BadgeId Example No visit last year
driver = GraphDatabase.driver(uri, auth=(username, password))
recommended_sessions = get_recommendations(visitor_id_example)

# %%
for session in recommended_sessions:
    print(session)
    print("*" * 25)
# Out:
# {'session_id': '49679', 'stream': 'Ophthalmology; Small Animal', 'title': 'What to look for - common ocular conditions on Brachycephalics', 'end_time': '12:00:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:10:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.83763087, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49684', 'stream': 'Behaviour; Small Animal', 'title': 'Handle with care: Fundamentals of behavioural first aid in general practice', 'end_time': '10:20:00', 'synopsis_stripped': "General practices are uniquely positioned to play a central role in the lifelong emotional health of companion animals - we are able to proactively ask owners about their pets’ behaviour, give preventative advice, and provide early interventions if problems arise. Unfortunately, many owners delay seeking veterinary help for their pet's behaviour until the problem is severe. Veterinarians can often feel poorly prepared to manage these challenging cases, especially within the time available in first\xa0opinion practice, and unsure of what advice to give. Behaviour first aid provides a flexible, practical framework for the first response to any behaviour problem. There is always something you can do to help, and a first aid approach helps pets and owners when they need it most. Learn how to take an effective behaviour history, investigate medical comorbidities, mitigate risk, and give actionable advice to optimise welfare and prevent the problem from getting worse.\xa0", 'sponsored_by': 'Forte Healthcare Ltd', 'start_time': '09:30:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.7382635, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49685', 'stream': 'Emergency Medicine; Small Animal', 'title': 'Take your own pulse first: CPR and how to survive running a crash.', 'end_time': '11:25:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.7312846, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49864', 'stream': 'Emergency Medicine; Nursing', 'title': 'Producing order in the chaos - preparing for CPR', 'end_time': '11:05:00', 'synopsis_stripped': 'It is widely accepted that CPR is stressful and can be chaotic at times. The level of the chaos and stress is something that as a team we can take steps to minimise. Using some simple actions, like cognitive aids to support decision making. Plus, utilising simulations to highlight any pinch points or areas for improvement. \nThis session will explore a range of interventions, from the time the patient is admitted to the clinic to the moment they are discharged. Exploring areas such a low number of rescuers, communication changes or drug doses and finally considering how we can set ourselves up for success with analysing and auditing the set up. Providing attendees with realistic and relatable tips for restoring order in the often-chaotic CPR.', 'sponsored_by': 'Not Sponsored', 'start_time': '10:15:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.72770375, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49676', 'stream': 'Emergency Medicine; Emergency Medicine; Small Animal; Small Animal', 'title': 'Stay or go? Discharge decisions for emergency cases?', 'end_time': '17:40:00', 'synopsis_stripped': 'Not every small animal emergency case requires hospitalisation, however determining which patients can be managed safely as outpatients can be challenging. When can a patient be safely managed at home? When is hospitalisation essential and when is homecare reasonable? This session will explore a practical approach to making admission decisions for common emergencies, including seizure patients, trauma cases, blocked cats, and those with haemorrhagic diarrhoea. We’ll then discuss a practical framework to balance clinical needs with pet-owner preferences and other considerations, with advice on setting realistic expectations and monitoring.', 'sponsored_by': 'Not Sponsored', 'start_time': '16:50:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.72332436, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49801', 'stream': 'Equine; Large Animal', 'title': 'Risk communication in the horse with colic: getting the best outcomes and preventing recurrence.', 'end_time': '14:20:00', 'synopsis_stripped': 'Colic is one of the most frequent reasons for emergency equine veterinary consultations in first opinion practice, with around 25% of cases requiring hospital admission. It is a major healthcare concern for horse owners and is one of the most common causes of equine morbidity and mortality. As veterinary professionals, it is important that we can use available evidence to inform owners about colic prevention and management, including the potential need for surgical intervention and likely outcomes following surgery. \xa0It is also important to use this information when making evidence-based decisions around veterinary care of the horse with colic. This lecture will cover the following: Common myths and challenges around communicating colic risk with horse owners; Identifying and managing the at-risk horse; Evidence-based approaches to veterinary diagnosis and management; Surgical outcomes based on the findings of the International Colic Surgery Audit (INCISE); Surgical procedures to reduce colic recurrence.', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.720765, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49803', 'stream': 'Equine; Large Animal', 'title': 'How to manage major trauma events', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.71268284, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49802', 'stream': 'Equine; Large Animal', 'title': 'Where do we start with recurrent colic: What is likely and how do I treat it?', 'end_time': '15:25:00', 'synopsis_stripped': 'The session will detail how to investigate recurrent colic, detailing how to use physical examination, endoscopy, abdominal ultrasound and clinical pathology in formulating a presumptive diagnosis. Treatment and management options will be covered. The session will be case based fostering an understanding of what causes recurrent abdominal pain, how it changes and the interplay between aetiology, clinical presentation, diagnostic imaging and treatment response.', 'sponsored_by': 'Not Sponsored', 'start_time': '14:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.7118011, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49810', 'stream': 'Farm; Large Animal', 'title': "Don't be allama'd! Triaging the emergency camelid case", 'end_time': '15:05:00', 'synopsis_stripped': 'Don’t Panic!\n\xa0\nAs the UK camelid population grows, there is an increasing demand for large animal practitioners to tend to alpaca and llama patients. A lack of understanding of their physiology and clinical quirks due to (until recently) little undergraduate teaching on the subject, can render novel or emergency camelid calls stressful. But don’t panic – you have many skills that are easily transferrable to camelids, and coupled with a little bit of nuanced knowledge, they can help you triage and treat emergency cases.\n\xa0\nBridge Knowledge Gaps\nPractices may be reluctant to take on a novel species, particularly one that can suffer from accelerated disease processes, carrying emotional and commercial value as both companions and commercial stock. In the author’s experience of working with camelids, it is evident that most owners wish to pursue diagnostics and embark upon schemes and practices that benefit their herd, which could be welcome news to vets already offering such services to different species. With insight from experienced production animal veterinarians, there is potential to reduce communicable disease transmission among other farmed species. It is therefore in all our interest that camelid owners are informed on matters of disease risk reduction and biosecurity – to do this, we must, as production vets, make efforts to extend clinical services in the hope of having these important discussions.\n\xa0\nSession Outline\nThis session aims to arm cattle practitioners with the skills required to undertake clinical examination and determine differential diagnoses for common, emergent camelid presentations. Emphasis will be put on breaking down camelid triage, and giving you east steps to provide first opinion care. It will identify differential diagnoses for common emergency presentations (with indicators of urgency) as well as identification of treatment pathways that are directly comparable to the more familiar species. Avenues for diagnostics will be discussed (as certain laboratory tests for common diseases can differ), and a camelid calendar will outline key times of year for risk periods.', 'sponsored_by': 'Bachelor of Veterinary Science', 'start_time': '14:25:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.7090983, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49861', 'stream': 'Emergency Medicine; Nursing', 'title': 'Managing the head trauma patient', 'end_time': '16:25:00', 'synopsis_stripped': 'The head trauma patient can be complex and require intensive nursing care. With a key focus on protecting the brain from any secondary damage. The major consideration with any head trauma is the traumatic brain injury. Careful nursing care is required with these patients. Holistic and well-planned care is crucial to these patient’s recovery. \nDuring the session methods of monitoring the patient, such as the Modified Glasgow Coma Score (MGCS) will be discussed and the application of this in a clinical setting explored. The Cushing’s response and the role it plays with the management of these patients will also be explained. Ending with nursing care, patient handling and condition specific considerations.', 'sponsored_by': 'Not Sponsored', 'start_time': '15:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.70796543, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49687', 'stream': 'Small Animal; Surgery', 'title': 'Blood, sweat & tears - how to avoid them in theatre', 'end_time': '14:20:00', 'synopsis_stripped': 'Patients haemorrhaging can be stressful during surgery and anaesthesia. This lecture focuses on how to prevent intra-operative and post-operative haemorrhage by identifying and managing risk factors and will include recognition and management of the physiological and clinical consequences of haemorrhage. \xa0A case-based approach will be used to discuss perioperative stabilisation and a variety of haemostasis techniques and practical tips for the general practitioner.', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.70599204, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49804', 'stream': 'Equine; Large Animal', 'title': 'Did someone call the vet? How to get teams of people to thrive under pressure.', 'end_time': '17:35:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '16:45:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6989263, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49811', 'stream': 'Farm; Large Animal', 'title': 'Introduction to deer vetting', 'end_time': '16:00:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Veterinary Dental Association', 'start_time': '15:20:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.69244075, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49800', 'stream': 'Equine; Large Animal', 'title': 'Point of care ultrasound: when will it help me?', 'end_time': '12:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.690272, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49865', 'stream': 'Cardiology; Nursing', 'title': 'Blood pressure monitoring & consults', 'end_time': '12:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:30:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.6875411, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49867', 'stream': 'Cardiology; Nursing', 'title': 'Interpreting ECGs and treating arrhythmias', 'end_time': '15:10:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '14:20:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.6872927, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49693', 'stream': 'Orthopaedics; Orthopaedics; Orthopaedics; Small Animal; Small Animal; Small Animal', 'title': 'Solving the lame dog… one step at a time', 'end_time': '12:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '11:55:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6850325, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49674', 'stream': 'Anaesthesia; Small Animal', 'title': 'Anaesthesia check lists: Do they protect our feline patients under GA?', 'end_time': '15:05:00', 'synopsis_stripped': 'This session will look at the history of anaesthesia check lists in both human and veterinary care. It will explore the evidence base around both their current utilisation and value, with the goal of understanding if they have a valuable role in protecting our feline patients.\xa0', 'sponsored_by': 'Not Sponsored', 'start_time': '14:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6837248, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49812', 'stream': 'Large Animal', 'title': 'Vets at the frontier of new and emerging diseases', 'end_time': '16:55:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Department for Environment, Food & Rural Affairs', 'start_time': '16:15:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6830474, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49697', 'stream': 'Equine; Large Animal', 'title': 'Neck pain in the horse, how do I spot it and what can I do next?', 'end_time': '10:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:30:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6820704, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49805', 'stream': 'Farm; Large Animal', 'title': "How to deal with small holder's and their sheep? Common issues and solutions!", 'end_time': '13:10:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Sheep Veterinary Society SVS', 'start_time': '12:30:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.68065715, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49682', 'stream': 'Oncology; Small Animal', 'title': 'The quest for comfort with cancer pain', 'end_time': '15:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '14:55:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6789262, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49691', 'stream': 'Neurology; Small Animal', 'title': 'Neurology - a video tour of seizures and their mimics', 'end_time': '10:35:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:45:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.67851365, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49690', 'stream': 'Feline; Small Animal', 'title': "Cat friendly interactions - avoiding 'cat' astrophes at the clinic", 'end_time': '17:35:00', 'synopsis_stripped': 'In this session we will explore the species-specific and individual needs of cats, and how these can influence their emotional state and behaviour at the veterinary clinic. We will look at what cat-friendly interactions are and the current evidence and resources available for veterinary professionals on this topic. We will discuss how applying cat-friendly techniques in the consult room aids with examinations and procedures and can help improve clinical outcomes of feline patients, whilst keeping the veterinary team safe and building trust with caregivers. Each cat and situation are different, so we will be thinking creatively and practically while examining some case-studies of how to troubleshoot and manage individual cats that are emotionally challenged when presented in the consulting room.', 'sponsored_by': 'Not Sponsored', 'start_time': '16:45:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6754823, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49698', 'stream': 'Equine; Large Animal', 'title': 'Wearable technology in the equine world: What works and how can I help my clients to use it?', 'end_time': '11:25:00', 'synopsis_stripped': 'Wearable technology use is growing in the equine world, and many owners have started using portable monitors to improve their horse’s welfare but also track their horse’s fitness journey. Unfortunately, the majority of these have not undergone scientific validation and therefore the data collected can be misleading in making decision about the horse’s fitness parameters. It is crucial to critically review validation data available for these devices prior to recommending or advising on their use, especially heart rate monitors and accelerometers as reliance on inaccurate data may be detrimental to the horse. However, validated monitors have an important role in the improvement of fitness programs tailored to each individual and in the prevention of catastrophic injuries in the sport horse, making them extremely valuable when interpreted appropriately. Helping clients understand the use and the limitations of these devices in assessing fitness is key to help optimizing training progress. The prophylactic properties of heart rate and accelerometers data should be integrated in the equine performance world, by helping prolong horses’ athletic careers but also from the welfare implications regarding safe animal use in sport disciplines. ', 'sponsored_by': 'Not Sponsored', 'start_time': '10:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6746761, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49807', 'stream': 'Farm; Large Animal', 'title': 'A toolkit for the pig visit', 'end_time': '12:15:00', 'synopsis_stripped': 'In this session, Gemma Thwaites and Pete Siviter will be providing an overview of husbandry, management and veterinary interventions in small scale pig herds. When faced with a pig visit, especially as a vet who does not specialise in this species, the difficulties surrounding handling and restraint can pose real problems so we will be giving advice on how physically to go about this in order to make the visit smoother and to manage your own (and clients’!) expectations. The second half of the session will be a ‘Question and Answer’, where we will take questions from the floor about common situations and how to deal with them – most particularly the methods available for euthanasia. Further resources and where to turn for help will be included as part of the session.', 'sponsored_by': 'Pig Veterinary Society', 'start_time': '11:35:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6738951, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49808', 'stream': 'Farm; Large Animal', 'title': "Treating pet dinosaurs: 3R's approach to preventative pet poultry medicine", 'end_time': '10:25:00', 'synopsis_stripped': 'What medications are most commonly used in pet hens and why? Are there alternative therapies or management options available to reduce, refine and replace antimicrobials in the most common presentations of pet hens?', 'sponsored_by': 'British Veterinary Poultry Association', 'start_time': '09:45:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.67267317, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49806', 'stream': 'Farm; Large Animal', 'title': 'Small farm and small holding cattle fertility', 'end_time': '11:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Bristol Commercial Valuers and Auctioneers', 'start_time': '10:40:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.6709426, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49671', 'stream': 'Dermatology; Small Animal', 'title': 'Itchy, scratchy cats: Where to start, when to use preds?', 'end_time': '11:05:00', 'synopsis_stripped': 'This session will discuss the various different clinical presentations seen in allergic cats. The approach to the pruritic cat will be discussed in detail and finally the treatment options available for managing cats wit feline atopic skin syndrome', 'sponsored_by': 'Not Sponsored', 'start_time': '10:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6643754, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49683', 'stream': 'Internal Medicine; Internal Medicine', 'title': 'Canine liver disease: the latest recommendations', 'end_time': '16:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '16:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.66284704, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49688', 'stream': 'Small Animal; Toxicology', 'title': 'Veterinary toxicology - past, present and future?', 'end_time': '15:25:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Small Animal Veterinary Association', 'start_time': '14:35:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.66166437, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49678', 'stream': 'Cardiology; Small Animal', 'title': 'I heard a murmur: determining the significance of heart murmurs in cats', 'end_time': '10:55:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:05:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.660552, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49692', 'stream': 'Internal Medicine', 'title': 'The diagnosis of liver disease', 'end_time': '11:40:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '10:50:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6558053, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49686', 'stream': 'Dentistry; Small Animal', 'title': 'We don’t have (dental) x-ray vision - interactive case-based small animal dentistry', 'end_time': '12:30:00', 'synopsis_stripped': 'Don’t have dental radiography in your small animal setting and wondering if you should take the plunge?Or do you have all the gear but you’re struggling to get good radiographs and interpret them?Then this session is for you!Using real cases, this session will explain the importance of dental radiographs, give tips on optimising your images, and guide you through what to do with your images when you have them.', 'sponsored_by': 'Not Sponsored', 'start_time': '11:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6556217, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49696', 'stream': 'Geriatric Medicine; Small Animal', 'title': 'Paws and peace - navigating end of life care for pets', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'British Small Animal Veterinary Association', 'start_time': '15:40:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6514561, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49675', 'stream': 'Gastroenterology; Small Animal', 'title': 'Do cats get IMHA? (Immune-mediated diseases and their treatment in cats)', 'end_time': '16:25:00', 'synopsis_stripped': 'This talk will be a case-based discussion of IMHA in cats. As part of the discussion of IMHA treatment, we will also consider other immune-mediated diseases in cats and their management.', 'sponsored_by': 'Not Sponsored', 'start_time': '15:35:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.65126646, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49680', 'stream': 'Obesity; Small Animal', 'title': 'Dealing with the clinical and functional consequences of obesity in dogs and cats', 'end_time': '13:05:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '12:15:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6505234, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '52369', 'stream': 'Career Development', 'title': 'The cost of adverse events: How small steps can prevent big mistakes', 'end_time': '13:00:00', 'synopsis_stripped': 'In the complex world of veterinary practice, things don’t always go as we plan or intend, despite the greatest effort and care. But what are the hidden costs of these events for all involved? And how could they become valuable opportunities to learn and improve?\nSupporting colleagues when things don’t go as we intend and cultivating a culture of continuous improvement that avoids blame and judgement is essential to developing thriving teams and businesses. \nDuring this session, our panel discussion will explore a human factors approach to reframing adverse events as opportunities for learning and improvement and the benefits this can have for all involved. Whatever your role in practice, unlock tools and perspectives that not only give you a greater awareness of how your practice is performing, but enable you to take real steps in driving meaningful improvement whilst cultivating a supportive learning culture.\xa0', 'sponsored_by': 'Not Sponsored', 'start_time': '12:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.6480659, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49695', 'stream': 'Exotic Animal; Exotic Animal', 'title': 'Antibiotic use in exotics - not just a baytril deficiency!', 'end_time': '15:25:00', 'synopsis_stripped': "The World Health Organisation states: Antimicrobial resistance (AMR) is one of the top global public health and development threats. It is estimated that bacterial AMR was directly responsible for 1.27 million global deaths in 2019 and contributed to 4.95 million deaths. As veterinary professionals we are responsible for our prescribing behaviour when it comes to antimicrobials. Our drug choices should be considered and the use of second or third line antibiotics justified. Drug selection is mutlifactorial and when it comes to exotics many vets will reach for 'Baytril' in exotic animals because it is licensed, it is considered a 'safe' drug in exotic species, it can be effective, and knowledge may be lacking of 'safe' alternatives nevermind the doses. Unfortunately, many of the infections in exotics we see are often secondary to stress induced immunocompromise resulting in normal microflora becoming opportunistic pathogens. Without correcting the underlying issue then at best we will achieve control not cure, leading to yet more antibiotics being prescribed.Antibiotic selection in exotics (mamamls,birds, reptiles) is a massive topic to cover in one session, so come join me for a whirlwind tour of drug selection, pain assessment, and husbandry considerations that will reduce the stress of the individual animal, promoting immunocompetance, and empower you to make logical drug choices of first line antibtiotics and know when it is appropriate to reach for the fluoroquinolones.", 'sponsored_by': 'Not Sponsored', 'start_time': '14:35:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6458513, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49868', 'stream': 'Anaesthesia; Nursing', 'title': 'Manual and mechanical ventilation and anaesthesia', 'end_time': '16:40:00', 'synopsis_stripped': 'Anaesthesia monitoring is a routine part of veterinary nurses\' daily responsibilities. With mechanical ventilators being one of the next pieces of equipment purchased in veterinary practices around the world, it has been recognised that aspects of monitoring and performing mechanical ventilation are not thoroughly covered in most curricula for veterinary nurses, let alone those pursuing post-graduate studies. This instills fear of using such equipment, misusing it, which could cause potential trauma to the patient, or not using it at all, resulting in a financial loss for the veterinary practice. For practices without a ventilator, there are tools available to make "bag squeezing" safer, but only if you know how to use them.', 'sponsored_by': 'Not Sponsored', 'start_time': '15:50:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.64461684, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49689', 'stream': 'Parasitology; Small Animal', 'title': 'Responsible prescribing of parasiticides: How and why dog & cat parasite prevention needs to change', 'end_time': '16:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:40:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.64396346, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49677', 'stream': 'Reproduction; Small Animal', 'title': 'Canine neutering in context: Who? When? Why?', 'end_time': '09:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6438154, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49694', 'stream': 'Respiratory; Small Animal', 'title': 'Why, when and how of BOAS assessment', 'end_time': '14:20:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '13:30:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 2', 'similarity_score': 0.6354505, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49670', 'stream': 'Endocrinology', 'title': 'Managing diabetes in 2025! 104 years after the first diabetic dog received insulin!', 'end_time': '09:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '09:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.6330641, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49681', 'stream': 'Gastroenterology', 'title': 'Scoop that poop: problem solving diarrhoea and constipation in cats', 'end_time': '14:40:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '13:50:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.62835586, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49866', 'stream': 'Diagnostics; Nursing', 'title': 'Lab skills for RVNs', 'end_time': '13:50:00', 'synopsis_stripped': 'Have you ever heard your vet say, “ I don’t trust those results, that machine is rubbish”? Have you ever questioned if the vet or the machine is correct? Do you want to know the common pitfalls in point of care haematology testing? During this session we will talk about common erroneous results in haematology and how to avoid them. We will also discuss the importance of a blood film examination and ways to ensure you are getting the best from your practice laboratory. Producing accurate and reliable results allow you to have a direct impact on patient outcomes as well as gaining the vets trust in the in-house laboratory.', 'sponsored_by': 'Not Sponsored', 'start_time': '13:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.6276834, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49809', 'stream': 'Farm; Large Animal', 'title': 'Catastrophic diseases of Honeybees…..the foulbroods', 'end_time': '14:10:00', 'synopsis_stripped': 'The two diseases , American Foulbrood and European Foulbrood, are very serious , potentially fatal bacterial diseases of honeybee colonies. They are called foulbrood because they affect the developing larvae which, when they die, produce a foul smelling odour. The diseases are global and have been known since ancient times. Aristotle described the conditions in his lifetime. American Foulbrood is caused by a rod shaped bacterium, Paenibacillus larvae, which exists in a spore form and a vegetative form. European Foulbrood is a bacterium, Melissococcus plutonius which does not sporulate. The pathogenesis of these infections are quite different and if left will destroy the colony. They are highly infectious and can easily spread with the behaviour of bees and the actions of beekeepers. Most European countries have these diseases classed as notifiable with the legal requirement that if suspected, it must be reported to the authorities for examination by a bee inspector. If a positive diagnosis is made, then mandatory destruction of the colony, with euthanasia and burning is required for AFB. EFB diagnosis will usually require euthanasia and burning but in some cases, shook swarm procedure or antibiotics can be utilized. Apiaries are placed on standstill until two clear inspections have occurred. Countries with a stringent bee inspection system have lower incidence, but because these bacteria are ubiquitous, it is unlikely that eradication can be achieved.', 'sponsored_by': 'British Bee Veterinary Association', 'start_time': '13:25:00', 'sponsored_session': 'True', 'date': '2025-06-13', 'theatre__name': 'Equine and Farm Clinical Theatre', 'similarity_score': 0.62746537, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '52371', 'stream': 'Debate', 'title': 'HOT TOPIC: Shaping the future: reforming the veterinary surgeons act and its impact', 'end_time': '11:25:00', 'synopsis_stripped': 'As the veterinary profession evolves, so must the framework that regulates it. Join experts from key organisations across the profession including the RCVS, BVNA, BVA and Vet Schools Council for a thought-provoking panel discussion on the future of the Veterinary Surgeons Act 1966 reform.\n\xa0\nListen to experts explore how the process for reforming the Veterinary Surgeons Act would take place. Learn about the challenges facing the profession, and the potential areas for change through reform. Understand the impact and benefit these changes could have for veterinary practices and the wider profession, including what this means for animal welfare, professional standards, and the future of the industry. Gain valuable insights, ask your questions, and be part of the conversation shaping the future of veterinary profession.', 'sponsored_by': 'Not Sponsored', 'start_time': '10:25:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.62716407, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49672', 'stream': 'Exotic Animal', 'title': 'It’s a knock out: Tips and tricks for successful small mammal anaesthesia', 'end_time': '12:35:00', 'synopsis_stripped': 'This talk will give an overview of how to prepare yourself (and your small mammal patient) for the ideal anaesthesia. Pre-operative, intra-operative and post-operative considerations will be discuss with species specific differences highlighted throughout.', 'sponsored_by': 'British Veterinary Zoological Society', 'start_time': '11:45:00', 'sponsored_session': 'True', 'date': '2025-06-12', 'theatre__name': 'Clinical Theatre 1', 'similarity_score': 0.62526786, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49860', 'stream': 'Anaesthesia; Nursing', 'title': 'Feline anaesthesia & analgesia', 'end_time': '14:50:00', 'synopsis_stripped': 'This lecture is designed to provide veterinary nurses with a comprehensive understanding of feline anaesthesia, focusing on best practices, protocols, and key considerations unique to cats. We will explore the physiological differences seen in felines that influence their anaesthetic management. Topics covered will include: 1. Pre-Anaesthetic Assessment: Importance of a thorough patient history, physical examination, and diagnostic tests to identify risks and ensure safe anaesthesia. 2. Analgesic Agents: Overview of commonly use analgesic drugs and protocols for cats. 3. Anaesthesia Protocols: Tailoring anaesthesia plans to the individual cat, considering factors such as age, breed, and underlying health conditions. 4. Airway management: How to safely intubate cats and how to manage complications of intubation. 5. Post-Anaesthetic Care: Ensuring a smooth recovery including hypothermia , and airway concerns that are known to be risk factors for cats in recovery. 6. Special Considerations: Addressing the unique challenges in feline anaesthesia, including considerations for high-risk cats such patients with trauma, cardiac and renal disease. This lecture aims to provide practical information on how to improve anaesthetic safety for cats.', 'sponsored_by': 'Not Sponsored', 'start_time': '14:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.624978, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49863', 'stream': 'Nursing; Wellbeing', 'title': 'How values and ethics can support and improve wellbeing', 'end_time': '09:50:00', 'synopsis_stripped': 'Increasingly there is talk in the veterinary world about moral injury and the ethical challenges veterinary professionals face. But what is the positive side? There are tools and systems that can help us feel that our values are respected and allow us to share our values and beliefs in ways that improve team cohesion and reduce client conflict. ', 'sponsored_by': 'Not Sponsored', 'start_time': '09:00:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.5998863, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49823', 'stream': 'Debate', 'title': 'Preparing for Change: The CMA Investigation, where we are and possible implications for the profession', 'end_time': '15:30:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '14:30:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5962802, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49862', 'stream': 'Career Development; Nursing', 'title': 'RVN progression into non-clinical roles', 'end_time': '17:50:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '17:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.5939625, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49859', 'stream': 'Animal Welfare; Feline; Nursing', 'title': "Improving our feline patients' hospital journey", 'end_time': '12:45:00', 'synopsis_stripped': 'This lecture is split into three parts. We will begin by refreshing some feline anatomy, behaviour and communication as well as the importance of reducing stress. I will share tips and tricks from within the nursing world and how to best set the scene in practice, while encouraging fear free handling. I will introduce my Happy Catty Pain Pie: a concept developed in practice, it is an eight part tool to educate about feline pain signalements beyond a numerical pain scoring system. We will then explore analgesic options and pain management. My aim is to empower nurses to be advocates for their patients and be able to exercise their skills and knowledge fully.', 'sponsored_by': 'Not Sponsored', 'start_time': '11:55:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'BVNA Nursing Theatre', 'similarity_score': 0.59129715, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49817', 'stream': 'Debate', 'title': 'Where is the UK on bTB control?', 'end_time': '16:15:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:15:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5685769, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '49824', 'stream': 'Career Development', 'title': 'I’m so scared to make a mistake as I know I’ll get blamed', 'end_time': '16:45:00', 'synopsis_stripped': 'No Data', 'sponsored_by': 'Not Sponsored', 'start_time': '15:45:00', 'sponsored_session': 'False', 'date': '2025-06-13', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.5428395, 'recommendation_reason': 'Similar to previously attended session'}
# *************************
# {'session_id': '53727', 'stream': 'Leadership', 'title': 'Leadership: why knowing yourself as a leader matters', 'end_time': '15:00:00', 'synopsis_stripped': 'This session will explore the crucial role self-awareness plays in effective leadership. Panellists will emphasise the role of understanding one’s strengths, weaknesses, values, and emotional triggers and how those allow leaders to make more informed decisions, build stronger teams, and foster a positive organisational culture. The session will delve into how self-reflection, emotional intelligence, and an authentic leadership style can improve communication, collaboration, and conflict resolution. The panel will also highlight the impact of self-awareness on leadership adaptability, empowering leaders to navigate change and manage diverse challenges. By knowing themselves, leaders can inspire trust and motivate others, creating an environment of growth and innovation', 'sponsored_by': 'Not Sponsored', 'start_time': '14:00:00', 'sponsored_session': 'False', 'date': '2025-06-12', 'theatre__name': 'Business, Careers and Debates Theatre', 'similarity_score': 0.51804805, 'recommendation_reason': 'Similar to previously attended session'}
# *************************

# %%
csv_file_path = "data/bva/output/df_reg_demo_this.csv"

# %%
data = pd.read_csv(csv_file_path)
len(data)
# Out:
# 1671

# %%
list_badgeId_this = list(data["BadgeId"].unique())
len(list_badgeId_this)
# Out:
# 1671

# %%
pa_recommendations = {}
counter = 0  # Initialize a counter

for badge in list_badgeId_this:
    recommended_sessions = get_recommendations(badge)
    pa_recommendations[badge] = recommended_sessions

    # Increment the counter
    counter += 1

    # Print the badge every 50 iterations
    if counter % 30 == 0:
        print(f"Processed {counter} badges so far. Current badge: {badge}")

# Optionally, print the total count at the end
print(f"Total badges processed: {counter}")
# Out:
# Processed 30 badges so far. Current badge: LKJE46Z
# Processed 60 badges so far. Current badge: 8IJK4ZH
# Processed 90 badges so far. Current badge: RMM5R3X
# Processed 120 badges so far. Current badge: 7EPPUF6
# Processed 150 badges so far. Current badge: CSLBS37
# Processed 180 badges so far. Current badge: 4FWYX7B
# Processed 210 badges so far. Current badge: V92DUSX
# Processed 240 badges so far. Current badge: UK6K7IT
# Processed 270 badges so far. Current badge: GF9AYQD
# Processed 300 badges so far. Current badge: 5A46ENN
# Processed 330 badges so far. Current badge: 8H5AXHZ
# Processed 360 badges so far. Current badge: LSJ7RX3
# Processed 390 badges so far. Current badge: 5N3VY39
# Processed 420 badges so far. Current badge: JUAZ7YQ
# Processed 450 badges so far. Current badge: J4AVZ8J
# Processed 480 badges so far. Current badge: 6MD33IP
# Processed 510 badges so far. Current badge: H7ZS3SY
# Processed 540 badges so far. Current badge: KE83IG8
# Processed 570 badges so far. Current badge: PUAWR7K
# Processed 600 badges so far. Current badge: G2H7AYE
# Processed 630 badges so far. Current badge: ERQX4E6
# Processed 660 badges so far. Current badge: WYIFQ7G
# Processed 690 badges so far. Current badge: T3CYJRT
# Processed 720 badges so far. Current badge: ZKPQXZ6
# Processed 750 badges so far. Current badge: ZSCVIJB
# Processed 780 badges so far. Current badge: EQ9WW9M
# Processed 810 badges so far. Current badge: 2TALLAA
# Processed 840 badges so far. Current badge: YKCDT5Z
# Processed 870 badges so far. Current badge: Q86GJJD
# Processed 900 badges so far. Current badge: QNWNXWL
# Processed 930 badges so far. Current badge: 6TFG94Z
# Processed 960 badges so far. Current badge: DRYQTAG
# Processed 990 badges so far. Current badge: 8WM8EV2
# Processed 1020 badges so far. Current badge: WRZR6MF
# Processed 1050 badges so far. Current badge: XKSZVR3
# Processed 1080 badges so far. Current badge: VKXLIEE
# Processed 1110 badges so far. Current badge: GJ86ZZW
# Processed 1140 badges so far. Current badge: 5KNDAU5
# Processed 1170 badges so far. Current badge: Y9RHFKX
# Processed 1200 badges so far. Current badge: 97IQ48M
# Processed 1230 badges so far. Current badge: KIJHKPI
# Processed 1260 badges so far. Current badge: AT4GSAE
# Processed 1290 badges so far. Current badge: 3SNQJB3
# Processed 1320 badges so far. Current badge: H8PY7K8
# Processed 1350 badges so far. Current badge: RZ2KH2P
# Processed 1380 badges so far. Current badge: ZD7G7HY
# Processed 1410 badges so far. Current badge: V3LQLP9
# Processed 1440 badges so far. Current badge: K2MWAPG
# Processed 1470 badges so far. Current badge: H4SJQ8U
# Processed 1500 badges so far. Current badge: 3JMNKAA
# Processed 1530 badges so far. Current badge: S52EVS9
# Processed 1560 badges so far. Current badge: H6HDCVQ
# Processed 1590 badges so far. Current badge: YCRZ6F4
# Processed 1620 badges so far. Current badge: 4KZGZY4
# Processed 1650 badges so far. Current badge: F22R9H8
# Total badges processed: 1671

# %%
import json

# %%
for key in pa_recommendations.keys():
    for ele in pa_recommendations[key]:
        ele["similarity_score"] = float(ele["similarity_score"])

# %%
count = 0
for key in pa_recommendations.keys():
    if len(pa_recommendations[key]) == 0:
        count += 1
print(count)
# Out:
# 178

# %%
with open("data/bva/bva_pa_recomendations.json", "w") as f:
    json.dump(pa_recommendations, f, indent=4)

# %%
pa_recommendations["Q5WEKRV"][0].keys()
# Out:
# dict_keys(['session_id', 'stream', 'title', 'end_time', 'synopsis_stripped', 'sponsored_by', 'start_time', 'sponsored_session', 'date', 'theatre__name', 'similarity_score', 'recommendation_reason'])

# %%
def transform_recommendations_to_dataframe(pa_recommendations):
    """
    Transforms a dictionary of session recommendations to a Pandas DataFrame.

    Args:
        pa_recommendations (dict): A dictionary where keys are badge IDs (strings)
            and values are lists of session dictionaries.  Each session dictionary
            contains information about a recommended session.

    Returns:
        pandas.DataFrame: A DataFrame with columns 'badgeid', 'session_id', 'stream',
            'title', 'end_time', 'synopsis_stripped', 'start_time', 'date',
            and 'theatre__name'. Returns an empty DataFrame if the input dictionary is empty.
    """

    data = []  # List to hold the rows of the DataFrame
    for badgeid, session_list in pa_recommendations.items():
        for session in session_list:
            row = {
                "badgeid": badgeid,
                "session_id": session.get("session_id", None),  # Use .get() for safety
                "stream": session.get("stream", None),
                "title": session.get("title", None),
                "synopsis_stripped": session.get("synopsis_stripped", None),
                "date": session.get("date", None),
                "start_time": session.get("start_time", None),
                "end_time": session.get("end_time", None),
                "theatre__name": session.get("theatre__name", None),
                "sponsored_by": session.get("sponsored_by", None),
                "similarity_score": session.get("similarity_score", None),
                "recommendation_reason": session.get("recommendation_reason", None),
            }
            data.append(row)

    df = pd.DataFrame(data)
    return df


df = transform_recommendations_to_dataframe(pa_recommendations)

# %%
df.head(10)
# Out:
#    badgeid session_id                                             stream  \
# 0  WGEBHVD      49686                            Dentistry; Small Animal
# 1  WGEBHVD      49693  Orthopaedics; Orthopaedics; Orthopaedics; Smal...
# 2  WGEBHVD      49677                         Reproduction; Small Animal
# 3  WGEBHVD      49694                          Respiratory; Small Animal
# 4  WGEBHVD      49689                         Parasitology; Small Animal
# 5  WGEBHVD      49680                              Obesity; Small Animal
# 6  WGEBHVD      49682                             Oncology; Small Animal
# 7  WGEBHVD      49696                   Geriatric Medicine; Small Animal
# 8  WGEBHVD      49684                            Behaviour; Small Animal
# 9  WGEBHVD      49679                        Ophthalmology; Small Animal
#
#                                                title  \
# 0  We don’t have (dental) x-ray vision - interact...
# 1           Solving the lame dog… one step at a time
# 2       Canine neutering in context: Who? When? Why?
# 3               Why, when and how of BOAS assessment
# 4  Responsible prescribing of parasiticides: How ...
# 5  Dealing with the clinical and functional conse...
# 6             The quest for comfort with cancer pain
# 7  Paws and peace - navigating end of life care f...
# 8  Handle with care: Fundamentals of behavioural ...
# 9  What to look for - common ocular conditions on...
#
#                                    synopsis_stripped        date start_time  \
# 0  Don’t have dental radiography in your small an...  2025-06-12   11:40:00
# 1                                            No Data  2025-06-13   11:55:00
# 2                                            No Data  2025-06-13   09:00:00
# 3                                            No Data  2025-06-13   13:30:00
# 4                                            No Data  2025-06-12   15:40:00
# 5                                            No Data  2025-06-13   12:15:00
# 6                                            No Data  2025-06-13   14:55:00
# 7                                            No Data  2025-06-13   15:40:00
# 8  General practices are uniquely positioned to p...  2025-06-12   09:30:00
# 9                                            No Data  2025-06-13   11:10:00
#
#    end_time       theatre__name                                 sponsored_by  \
# 0  12:30:00  Clinical Theatre 2                                Not Sponsored
# 1  12:45:00  Clinical Theatre 2                                Not Sponsored
# 2  09:50:00  Clinical Theatre 1                                Not Sponsored
# 3  14:20:00  Clinical Theatre 2                                Not Sponsored
# 4  16:30:00  Clinical Theatre 2                                Not Sponsored
# 5  13:05:00  Clinical Theatre 1                                Not Sponsored
# 6  15:45:00  Clinical Theatre 1                                Not Sponsored
# 7  16:30:00  Clinical Theatre 2  British Small Animal Veterinary Association
# 8  10:20:00  Clinical Theatre 2                         Forte Healthcare Ltd
# 9  12:00:00  Clinical Theatre 1                                Not Sponsored
#
#    similarity_score                           recommendation_reason
# 0          0.826089  Similar to session attended by similar visitor
# 1          0.734745  Similar to session attended by similar visitor
# 2          0.727049  Similar to session attended by similar visitor
# 3          0.724030  Similar to session attended by similar visitor
# 4          0.720899  Similar to session attended by similar visitor
# 5          0.720224  Similar to session attended by similar visitor
# 6          0.718594  Similar to session attended by similar visitor
# 7          0.714789  Similar to session attended by similar visitor
# 8          0.714349  Similar to session attended by similar visitor
# 9          0.711267  Similar to session attended by similar visitor

# %%
import pandas as pd
import numpy as np


def flag_overlapping_sessions(df):
    # Create a copy to avoid modifying the original
    df = df.copy()

    # Convert string time columns to datetime
    df["start_datetime"] = pd.to_datetime(df["date"] + " " + df["start_time"])
    df["end_datetime"] = pd.to_datetime(df["date"] + " " + df["end_time"])

    # Initialize the overlapping_sessions column
    df["overlapping_sessions"] = None

    # Process each badge group
    for badge_id, group in df.groupby("badgeid"):
        # Skip if only one session
        if len(group) <= 1:
            continue

        # Get indices in the original dataframe
        group_indices = group.index

        # For each session in the group
        for i, idx in enumerate(group_indices):
            # Get current session times
            current_start = df.loc[idx, "start_datetime"]
            current_end = df.loc[idx, "end_datetime"]
            current_id = df.loc[idx, "session_id"]

            # Create mask for overlapping sessions (vectorized comparison)
            # A session overlaps if it starts before current ends AND ends after current starts
            mask = (
                (group["start_datetime"] < current_end)
                & (group["end_datetime"] > current_start)
                & (group["session_id"] != current_id)
            )

            # Get overlapping session IDs
            overlapping_ids = group.loc[mask, "session_id"].tolist()

            # Update if overlaps found
            if overlapping_ids:
                df.at[idx, "overlapping_sessions"] = ",".join(map(str, overlapping_ids))

    # Drop the temporary datetime columns
    df.drop(["start_datetime", "end_datetime"], axis=1, inplace=True)

    return df


# Apply the function to your DataFrame
df = flag_overlapping_sessions(df)

# %%
df.overlapping_sessions.value_counts()
# Out:
# overlapping_sessions
# 49684,49697                            1004
# 49681,49809                             926
# 49686,49672                             904
# 49691,49808                             860
# 49800,49672                             799
#                                        ...
# 49670,49858,49671,49857,49697             1
# 49696,49695,49867,49811,49810,49823       1
# 49691,49692,49864,49806,49808             1
# 49680,49679,49865,52369,49805,49807       1
# 49687,49860,49801,49802,49674,49688       1
# Name: count, Length: 1938, dtype: int64

# %%
df.head(2)
# Out:
#    badgeid session_id                                             stream  \
# 0  WGEBHVD      49686                            Dentistry; Small Animal
# 1  WGEBHVD      49693  Orthopaedics; Orthopaedics; Orthopaedics; Smal...
#
#                                                title  \
# 0  We don’t have (dental) x-ray vision - interact...
# 1           Solving the lame dog… one step at a time
#
#                                    synopsis_stripped        date start_time  \
# 0  Don’t have dental radiography in your small an...  2025-06-12   11:40:00
# 1                                            No Data  2025-06-13   11:55:00
#
#    end_time       theatre__name   sponsored_by  similarity_score  \
# 0  12:30:00  Clinical Theatre 2  Not Sponsored          0.826089
# 1  12:45:00  Clinical Theatre 2  Not Sponsored          0.734745
#
#                             recommendation_reason  \
# 0  Similar to session attended by similar visitor
# 1  Similar to session attended by similar visitor
#
#             overlapping_sessions
# 0                    49672,49800
# 1  49680,49679,49805,49807,52369

# %%
len(df)
# Out:
# 74702

# %%
df.to_csv("data/bva/bva_pa_recomendations.csv", index=False)

# %%
df["recommendation_reason"].unique()
# Out:
# array(['Similar to session attended by similar visitor',
#        'Similar to previously attended session'], dtype=object)

# %% [markdown]
# # ADD registration Demo Information

# %%
data.columns
# Out:
# Index(['Email', 'Email_domain', 'Company', 'JobTitle', 'Country', 'BadgeType',
#        'ShowRef', 'BadgeId', 'Source', 'Days_since_registration',
#        'assist_year_before', 'BadgeId_last_year_bva', 'BadgeId_last_year_lva',
#        'what_type_does_your_practice_specialise_in', 'organisation_type',
#        'job_role'],
#       dtype='object')

# %%
data.columns = [
    "Email",
    "Email_domain",
    "Company",
    "JobTitle",
    "Country",
    "BadgeType",
    "ShowRef",
    "badgeid",
    "Source",
    "Days_since_registration",
    "assist_year_before",
    "BadgeId_last_year_bva",
    "BadgeId_last_year_lva",
    "what_type_does_your_practice_specialise_in",
    "organisation_type",
    "job_role",
]

# %%
data_final = pd.merge(df, data, on=["badgeid"], how="left")

# %%
len(df), len(data_final)
# Out:
# (74702, 74702)

# %%
data_final.to_csv("data/bva/bva_pa_recomendations_with_demo.csv", index=False)

# %%
## OLD Stuff

# %%
# from graphdatascience import GraphDataScience

# # Connect to Neo4j (Please update URI, USER and PASSWORD )
# NEO4J_URI =  "bolt://127.0.0.1:7687"
# USER = "neo4j"
# PASSWORD = "Larisa10@"

# # Connect to Neo4j
# gds = GraphDataScience(NEO4J_URI, auth=(USER, PASSWORD))

# # Check existing relationships
# existing_rels = gds.run_cypher("CALL db.relationshipTypes()")
# print("Existing Relationship Types in database:")
# print(existing_rels)
# Out:
# Existing Relationship Types in database:
#    relationshipType
# 0        HAS_STREAM
# 1      Same_Visitor
# 2  attended_session

# %%
# # Adjust these variables exactly as they appear in the print statement above
# SAME_PERSON_REL = "Same_Visitor"          # <-- adjust as per exact output
# ATTENDED_SESSION_REL = "attended_session" # <-- adjust as per exact output
# HAS_STREAM_REL = "HAS_STREAM"             # <-- adjust as per exact output

# graph_name = "visitor_session_graph"

# %%
# # Drop the graph if previously exists
# if gds.graph.exists(graph_name)["exists"]:
#     gds.graph.drop(graph_name)

# %%
# MATCH (node:Label)
# WHERE node.propertyName = "Embeddings"
# MATCH (node:Visitor_last_year)
# SET node.Embeddings = null

# %%
# # Re-create graph with correctly adjusted relationship names
# try:
#     g, result = gds.graph.project(
#         graph_name,
#         ['Visitor_this_year'],
#         {
#             SAME_PERSON_REL: {'orientation': 'UNDIRECTED'},

#         }
#     )
#     print(f"Graph '{graph_name}' projected successfully:")
#     print(result)

# except Exception as e:
#     print("Failed to project graph:")
#     print(e)
# Out:
# Graph 'visitor_session_graph' projected successfully:
# nodeProjection            {'Visitor_this_year': {'label': 'Visitor_this_...
# relationshipProjection    {'Same_Visitor': {'aggregation': 'DEFAULT', 'o...
# graphName                                             visitor_session_graph
# nodeCount                                                              1317
# relationshipCount                                                         0
# projectMillis                                                             7
# Name: 0, dtype: object

# %%
# # STEP 2 - FastRP Embeddings for each Node Type individually
# EMBEDDING_SIZE = 128

# # Function to generate embeddings
# def generate_embeddings(label, embedding_property):
#     result = gds.fastRP.write(
#         g,
#         embeddingDimension=EMBEDDING_SIZE,
#         iterationWeights=[0.8, 1, 1, 1],
#         nodeLabels=[label],
#         writeProperty=embedding_property
#     )
#     print(f"Embeddings created for nodes '{label}' written to property '{embedding_property}':")
#     print(result)

# %%
# Visitor_last_year embeddings
generate_embeddings("Visitor_this_year", "Embeddings")
# Out:
# Embeddings created for nodes 'Visitor_this_year' written to property 'Embeddings':
# nodeCount                                                             1317
# nodePropertiesWritten                                                 1317
# preProcessingMillis                                                      0
# computeMillis                                                           14
# writeMillis                                                             76
# configuration            {'writeProperty': 'Embeddings', 'jobId': 'ba33...
# Name: 0, dtype: object
