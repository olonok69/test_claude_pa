# %%
import requests
import mimetypes
import json

# %%
query = {
    "pit": {

        "id": ""

    },
    "query":{
        "bool":{
         "must":[
            {
               "exists":{
                  "field":"content"
               }
            },
            {
               "bool":{
                  "should":[
                     {
                        "term":{
                           "file_type":"docx"
                        }
                     },
                     {
                        "term":{
                           "file_type":"doc"
                        }
                     },
                       {
                        "term":{
                           "file_type":"pdf"
                        }
                     }
                  ]
                    
               }
            },
            {
               "range":{
                  "fs.size":{
                     "gt":100,
                     "lt":5000000000
                  }
               }
            }
         ]
      }
   },
    "from": 0,
    "size": 10000,
    "sort": [
        {
            "fs.size": {
                "order": "asc"
            }
        }
    ]
}

# %%
data = {}
data['query'] = query
data['type'] = "search_v2" # ingest or search
data['index'] = "control_data_set_5_resumes_demo-doc"
data['index_post'] = "control_data_set_5_resumes_demo-doc-semantic"
data['num_docs'] = 5
data['file_types_all'] = 'False'
data['filenames_types']= ["doc", "docx", "pdf"]
data
# Out:
# {'query': {'pit': {'id': ''},
#   'query': {'bool': {'must': [{'exists': {'field': 'content'}},
#      {'bool': {'should': [{'term': {'file_type': 'docx'}},
#         {'term': {'file_type': 'doc'}},
#         {'term': {'file_type': 'pdf'}}]}},
#      {'range': {'fs.size': {'gt': 100, 'lt': 5000000000}}}]}},
#   'from': 0,
#   'size': 10000,
#   'sort': [{'fs.size': {'order': 'asc'}}]},
#  'type': 'search_v2',
#  'index': 'control_data_set_5_resumes_demo-doc',
#  'labels': 'fashion_business_finance_human resources_technology_international_politics_health_family_education_energy_mining_resume',
#  'num_docs': 5,
#  'file_types_all': 'False',
#  'filenames_types': ['doc', 'docx', 'pdf']}

# %%
data1 = json.dumps(data).encode()

# %%
# Semantic similarity
url = "http://localhost:5006/semantic_search_create_model" 
# fin = open(f'../notebooks/test_docs/query2.json', 'rb')
# query
#data=fin.read()

#files = {'file': fin}
try:
    r = requests.post(url, data=data1)#files=files)
    print(r.text)
finally:

    pass
# Out:
# "{\n  \"status\": \"SUCCESS\",\n  \"Number doc read \": \"165\",\n  \"Total Time\": \"0:05:27.740140\"\n}"

# %%
res ="{\n  \"status\": \"SUCCESS\",\n  \"Number doc read \": \"165\",\n  \"Total Time\": \"0:05:27.740140\"\n}"
eval(res)
# Out:
# {'status': 'SUCCESS',
#  'Number doc read ': '165',
#  'Total Time': '0:05:27.740140'}

# %%
#
data = {}

data['questions'] = "university job history experience school skill institute education professional training certifications"
data['index'] = "control_data_set_5_resumes_demo-doc" # large_control_dataset-doc, unbias_it_data-doc
data['rank'] =  "5"
data
# Out:
# {'questions': 'university job history experience school skill institute education professional training certifications',
#  'index': 'control_data_set_5_resumes_demo-doc',
#  'rank': '5'}

# %%
data2 = json.dumps(data).encode()

# %%
url = "http://localhost:5006/semantic_search_query_model" 
# fin = open(f'../notebooks/test_docs/query2.json', 'rb')
# query
#data=fin.read()

#files = {'file': fin}
try:
    r = requests.post(url, data=data2)#files=files)
    print(r.text)
finally:

    pass
# Out:
# "[{\"scan_id\": \"0192699d1d7ef8374eecf4c069bfa0b8d81442afaef4d3713cfca8ffe95ddf11\", \"score\": \"0.16870403992366106\", \"text\": \"  MARK KORRES\\n\\n  9561 Arrowhead Dr. Hickory Hills, IL 60457 \\u2022 (773) 297-3450 \\u2022 mark@markkorres.com\\n\\n  Page 1 of 2\\n\\n  SUMMARY\\n\\n  An IT Service Management, ITIL certified technical professional with a breadth of experience teaching, designing,\\n\\n  implementing, and improving IT operations, processes, and frameworks. A leader that emphasizes team success\\n\\n  and inspires desired outcomes and increased performance with a cross-industry designation and deep experience in\\n\\n  Life Sciences, Healthcare, Energy, and Insurance/Financial industries for Fortune 500 and large companies.\\n\\n  Extensive experience leading IT transformations, implementing major initiatives, designing processes, creating\\n\\n  proposals, responding to RFPs/RFIs, mentoring counselees, and managing infrastructure teams. Recent\\n\\n  accomplishments include a Continuous Service Improvement implementation that produced a 60% decrease in\\n\\n  Priority 1 incidents and an 80% improvement in average resolution time and the creation of a three-year roadmap to\\n\\n  save the client $4.6M annually in addition to $6M in qualitative benefits. Open to travel.\\n\\n  EXPERIENCE\\n\\n  \\u27a2 ITIL/ITSM Expertise\\n\\n  \\u2022 Led redesign of core ITSM processes including workshops, interviews. Created process documentation, training\\n\\n  guides and completed train the trainer sessions. Redesigned meta-data for the current and future ITSM tools and\\n\\n  documented pre-requisites for recommended ITSM tool.\\n\\n  \\u2022 Designed and implemented an ITSM governance structure to address ITSM improvements and prioritize\\n\\n  projects. Mentored client process owners to create improvement projects and charters. Identified 60+ initiatives\\n\\n  and 20+ projects to support the ITSM Strategy and implement it the over three years.\\n\\n  \\u2022 Responsible for regional and global service implementation across 3 regions for trading applications using ITIL\\n\\n  standards including governance and a standardized CMDB.\\n\\n  \\u2022 Developed Service Catalogs, Service Request processes and roadmaps to implement with SLAs and KPIs.\\n\\n  \\u2022 Served as IT Service Management Liaison for all Acquisitions and Divestitures.\\n\\n  \\u27a2 Service Improvement / Application Rationalization / IT Operating Model\\n\\n  \\u2022 Led ITSM Tool assessment that included 500+ IT Tools and 380K+ users resulting in $4.6M annual savings.\\n\\n  \\u2022 Recommended transition from a legacy tool to ServiceNow to save the organization $1M+ yearly.\\n\\n  \\u2022 Assessed current IT Operating Model, including value of major tools and applications for CIO and CFO\\n\\n  decisions. Developed a plan to reduce IT spend and target a 3% IT cost and a go-forward IT Operating Model\\n\\n  with a $13M reduction in IT cost. Produced a 14-month roadmap to implement projects and transform to new\\n\\n  operating model.\\n\\n  \\u2022 Lead Strategy to convert from Remedy to ServiceNow, including the definition of Service Catalog offerings,\\n\\n  data elements and workflow. Coordinated Service Management processes with ServiceNow workflows and\\n\\n  implemented Incident, Change, Problem, Release, Configuration, Asset, Knowledge, Event, SCM and SLM.\\n\\n  \\u2022 Developed and Managed the \\u201cAvailability is Job #1\\u201d Program which resulted in: reduction of P1 Incident Count\\n\\n  by 60% and P1 Duration by 80%, eliminated outages during planned Infrastructure Maintenance, eliminated\\n\\n  authentication P1 incidents, Reduced the number P1s due to Change, and reduced the backlog of open Root\\n\\n  Cause Analysis tickets by 90%.\\n\\n  \\u27a2 Proposals / RFPs\\n\\n  \\u2022 Led team of 20+ to create 70+ page proposal and several supporting presentations to win ServiceNow\\n\\n  implementation for large financial client.\\n\ ...

# %%
output = "{\"scan_id\": \"0192699d1d7ef8374eecf4c069bfa0b8d81442afaef4d3713cfca8ffe95ddf11\", \"score\": \"0.16870403992366106\", \"text\": \"  MARK KORRES\\n\\n  9561 Arrowhead Dr. Hickory Hills, IL 60457 \\u2022 (773) 297-3450 \\u2022 mark@markkorres.com\\n\\n  Page 1 of 2\\n\\n  SUMMARY\\n\\n  An IT Service Management, ITIL certified technical professional with a breadth of experience teaching, designing,\\n\\n  implementing, and improving IT operations, processes, and frameworks. A leader that emphasizes team success\\n\\n  and inspires desired outcomes and increased performance with a cross-industry designation and deep experience in\\n\\n  Life Sciences, Healthcare, Energy, and Insurance/Financial industries for Fortune 500 and large companies.\\n\\n  Extensive experience leading IT transformations, implementing major initiatives, designing processes, creating\\n\\n  proposals, responding to RFPs/RFIs, mentoring counselees, and managing infrastructure teams. Recent\\n\\n  accomplishments include a Continuous Service Improvement implementation that produced a 60% decrease in\\n\\n  Priority 1 incidents and an 80% improvement in average resolution time and the creation of a three-year roadmap to\\n\\n  save the client $4.6M annually in addition to $6M in qualitative benefits. Open to travel.\\n\\n  EXPERIENCE\\n\\n  \\u27a2 ITIL/ITSM Expertise\\n\\n  \\u2022 Led redesign of core ITSM processes including workshops, interviews. Created process documentation, training\\n\\n  guides and completed train the trainer sessions. Redesigned meta-data for the current and future ITSM tools and\\n\\n  documented pre-requisites for recommended ITSM tool.\\n\\n  \\u2022 Designed and implemented an ITSM governance structure to address ITSM improvements and prioritize\\n\\n  projects. Mentored client process owners to create improvement projects and charters. Identified 60+ initiatives\\n\\n  and 20+ projects to support the ITSM Strategy and implement it the over three years.\\n\\n  \\u2022 Responsible for regional and global service implementation across 3 regions for trading applications using ITIL\\n\\n  standards including governance and a standardized CMDB.\\n\\n  \\u2022 Developed Service Catalogs, Service Request processes and roadmaps to implement with SLAs and KPIs.\\n\\n  \\u2022 Served as IT Service Management Liaison for all Acquisitions and Divestitures.\\n\\n  \\u27a2 Service Improvement / Application Rationalization / IT Operating Model\\n\\n  \\u2022 Led ITSM Tool assessment that included 500+ IT Tools and 380K+ users resulting in $4.6M annual savings.\\n\\n  \\u2022 Recommended transition from a legacy tool to ServiceNow to save the organization $1M+ yearly.\\n\\n  \\u2022 Assessed current IT Operating Model, including value of major tools and applications for CIO and CFO\\n\\n  decisions. Developed a plan to reduce IT spend and target a 3% IT cost and a go-forward IT Operating Model\\n\\n  with a $13M reduction in IT cost. Produced a 14-month roadmap to implement projects and transform to new\\n\\n  operating model.\\n\\n  \\u2022 Lead Strategy to convert from Remedy to ServiceNow, including the definition of Service Catalog offerings,\\n\\n  data elements and workflow. Coordinated Service Management processes with ServiceNow workflows and\\n\\n  implemented Incident, Change, Problem, Release, Configuration, Asset, Knowledge, Event, SCM and SLM.\\n\\n  \\u2022 Developed and Managed the \\u201cAvailability is Job #1\\u201d Program which resulted in: reduction of P1 Incident Count\\n\\n  by 60% and P1 Duration by 80%, eliminated outages during planned Infrastructure Maintenance, eliminated\\n\\n  authentication P1 incidents, Reduced the number P1s due to Change, and reduced the backlog of open Root\\n\\n  Cause Analysis tickets by 90%.\\n\\n  \\u27a2 Proposals / RFPs\\n\\n  \\u2022 Led team of 20+ to create 70+ page proposal and several supporting presentations to win ServiceNow\\n\\n  implementation for large financial client.\\n\\n  \\u2022 Led large and small teams to create multiple winning proposals for Fortune 500 Life Sciences/Healthcare,\\n\\n  Energy, and Insurance/Financial clients.\\n\\n  \\u2022 RFP Response team member developing and submitting RFP follow-up and clarifying questions.\\n\\n  \\u2022 Presentation team member for multiple proposals\\n\\n  \\u27a2 Assessments / Improvement Roadmaps\\n\\n  \\u2022 Led multiple ITSM Maturity Assessments and helped develop and ITSM Maturity Assessment Tool.\\n\\n  \\u2022 Led ITSM and PPM Assessments identifying pain points, creating future states, and performing gap analysis.\\n\\n  \\u2022 Developed prioritization tools to help clients focus on quick wins and long-term benefits.\\n\\n  \\u2022 Created multiple-year roadmaps plotting project sequence and identifying key dependencies and risks.\\n\\n  MARK KORRES\\n\\n  9561 Arrowhead Dr. Hickory Hills, IL 60457 \\u2022 (773) 297-3450 \\u2022 mark@markkorres.com\\n\\n  Page 2 of 2\\n\\n  JOB HISTORY\\n\\n  \\u27a2 Deloitte Consulting * 7/17 \\u2013 Present\\n\\n  Manager \\u2013 ServiceNow, ITSM and Service Management Practice\\n\\n  Led engagements for multiple, national, and global Fortune 500 clients (Life Sciences/Healthcare, Financial and\\n\\n  Energy) to perform ITSM/ITIL/Maturity assessments, gap analysis, and create roadmaps for improvement and\\n\\n  implementation. Led teams to create Sales Proposals and RFP responses. Served as practice lead for interviewing\\n\\n  and hiring new resources. Mentored multiple counselees and assisted with career development and firm success.\\n\\n  \\u27a2 TEK Systems * 8/12 \\u2013 7/17\\n\\n  Managing Consultant \\u2013 ITIL / IT Service Management\\n\\n  Served as ITIL and ITSM Subject Matter Expert and Manager. Led several ITSM, ITIL and Service Improvement\\n\\n  engagements for multiple Insurance/Financial Chicago area companies.\\n\\n  \\u27a2 The ACE Group * 7/11 \\u2013 8/12\\n\\n  Service Manager, Combined Insurance, North America\\n\\n  Implemented a Service Improvement Program to streamline service processes, eliminate impactful outages and\\n\\n  increase overall availability. Instituted a Communication Policy for all desktop distributions reducing the number of\\n\\n  secondary distributions and outages due to lack of application access.\\n\\n  \\u27a2 TEK Systems * 4/10 \\u2013 7/11\\n\\n  Managing Consultant \\u2013 ITIL / IT Service Management\\n\\n  Served as ITIL and ITSM Subject Matter Expert and Manager. Led several ITSM, ITIL and Service Improvement\\n\\n  engagements for multiple Insurance/Financial Chicago area companies.\\n\\n  \\u27a2 Fruition Partners * 8/07 \\u2013 4/10\\n\\n  Consultant \\u2013 ITIL / IT Service Management / ServiceNow\\n\\n  Led engagements for multiple, national, and global clients (Travel, Financial and Energy) to perform\\n\\n  ITSM/ITIL/Maturity assessments, gap analysis, and create roadmaps for improvement and implementation. Led\\n\\n  teams to create Sales Proposals and RFP responses. Taught ITIL certification classes. Team member selected to\\n\\n  review first ServiceNow Administration Guide.\\n\\n  \\u27a2 Northern Trust * 2/03 \\u2013 8/07\\n\\n  Vice-President, Certification/Deployment Coordinator\\n\\n  Designed and Implemented new certification and release/deployment process for all desktop applications and\\n\\n  managed 800+ applications for 14K+ endpoints world-wide. Planned 4K+ deployments/certifications/releases and\\n\\n  became integral part of Initial Review and PMO processes. Designed and Implemented application/distribution\\n\\n  tracking database and Deployment Tracking Database to record necessary deployment information\\n\\n  EDUCATION / CERTIFICATIONS\\n\\n  \\u2022 ServiceNow Certified Implementation Specialist\\n\\n  \\u2022 ITIL V3 Foundations Certified \\u2013 Exin U.S.A.\\n\\n  \\u2022 Ed Jones \\\"Train-the-Trainer\\\" seminars\\n\\n  \\u2022 Illinois Institute of Technology \\u2013 CS / EE\\n\\n  \\u2022 Illinois State Scholar - National Honor Society\\n\\n  \\u2022 Who's Who in American High School Students\\n\\n  GENERAL ASSETS\\n\\n  * ITIL, Cobit, IT Service Management\\n\\n  * ServiceNow (ITSM, ITOM, ITBM, CSDM), Remedy, IBM Maximo, LANDesk, Track-IT, Magic Helpdesk\\n\\n  * Teams, SharePoint, InfoPath, Hyperion, MS Access, HTML, Java Scripts, Citrix\\n\\n  * Windows, Microsoft Office, MS Project, Visio, Exchange, Lotus Notes, Google Apps, QuickBooks, Timberline\\n\\n  * Familiar with Novell, UNIX, Linux, MS SQL, Sybase, Oracle, Paradox, CGI, Perl, Cold Fusion, Visual Basic\\n\\n  * 20 + Years of Management, Training, and Customer Service experience\\n\\n  * Excellent Organizational, Interpersonal, Training and Developmental Skills\\n\\n  * A generally nice guy\\n\\n  FULL CV AND REFERENCES AVAILABLE UPON REQUEST\\n\"}"
eval(output)
# Out:
# {'scan_id': '0192699d1d7ef8374eecf4c069bfa0b8d81442afaef4d3713cfca8ffe95ddf11',
#  'score': '0.16870403992366106',
#  'text': '  MARK KORRES\n\n  9561 Arrowhead Dr. Hickory Hills, IL 60457 • (773) 297-3450 • mark@markkorres.com\n\n  Page 1 of 2\n\n  SUMMARY\n\n  An IT Service Management, ITIL certified technical professional with a breadth of experience teaching, designing,\n\n  implementing, and improving IT operations, processes, and frameworks. A leader that emphasizes team success\n\n  and inspires desired outcomes and increased performance with a cross-industry designation and deep experience in\n\n  Life Sciences, Healthcare, Energy, and Insurance/Financial industries for Fortune 500 and large companies.\n\n  Extensive experience leading IT transformations, implementing major initiatives, designing processes, creating\n\n  proposals, responding to RFPs/RFIs, mentoring counselees, and managing infrastructure teams. Recent\n\n  accomplishments include a Continuous Service Improvement implementation that produced a 60% decrease in\n\n  Priority 1 incidents and an 80% improvement in average resolution time and the creation of a three-year roadmap to\n\n  save the client $4.6M annually in addition to $6M in qualitative benefits. Open to travel.\n\n  EXPERIENCE\n\n  ➢ ITIL/ITSM Expertise\n\n  • Led redesign of core ITSM processes including workshops, interviews. Created process documentation, training\n\n  guides and completed train the trainer sessions. Redesigned meta-data for the current and future ITSM tools and\n\n  documented pre-requisites for recommended ITSM tool.\n\n  • Designed and implemented an ITSM governance structure to address ITSM improvements and prioritize\n\n  projects. Mentored client process owners to create improvement projects and charters. Identified 60+ initiatives\n\n  and 20+ projects to support the ITSM Strategy and implement it the over three years.\n\n  • Responsible for regional and global service implementation across 3 regions for trading applications using ITIL\n\n  standards including governance and a standardized CMDB.\n\n  • Developed Service Catalogs, Service Request processes and roadmaps to implement with SLAs and KPIs.\n\n  • Served as IT Service Management Liaison for all Acquisitions and Divestitures.\n\n  ➢ Service Improvement / Application Rationalization / IT Operating Model\n\n  • Led ITSM Tool assessment that included 500+ IT Tools and 380K+ users resulting in $4.6M annual savings.\n\n  • Recommended transition from a legacy tool to ServiceNow to save the organization $1M+ yearly.\n\n  • Assessed current IT Operating Model, including value of major tools and applications for CIO and CFO\n\n  decisions. Developed a plan to reduce IT spend and target a 3% IT cost and a go-forward IT Operating Model\n\n  with a $13M reduction in IT cost. Produced a 14-month roadmap to implement projects and transform to new\n\n  operating model.\n\n  • Lead Strategy to convert from Remedy to ServiceNow, including the definition of Service Catalog offerings,\n\n  data elements and workflow. Coordinated Service Management processes with ServiceNow workflows and\n\n  implemented Incident, Change, Problem, Release, Configuration, Asset, Knowledge, Event, SCM and SLM.\n\n  • Developed and Managed the “Availability is Job #1” Program which resulted in: reduction of P1 Incident Count\n\n  by 60% and P1 Duration by 80%, eliminated outages during planned Infrastructure Maintenance, eliminated\n\n  authentication P1 incidents, Reduced the number P1s due to Change, and reduced the backlog of open Root\n\n  Cause Analysis tickets by 90%.\n\n  ➢ Proposals / RFPs\n\n  • Led team of 20+ to create 70+ page proposal and several supporting presentations to win ServiceNow\n\n  implementation for large financial client.\n\n  • Led large and small teams to create multiple winning proposals for Fortune 500 Life Sciences/Healthcare,\n\n  Energy, and Insurance/Financial clients.\n\n  • RFP Response team member developing and submitting RFP follow-up and clarifying questions.\n\n  • Presentation team member for multiple proposals\n\n  ➢ ...

# %%
out = r.json()
out = eval(out)

# %%
for ele in out:
    #print(ele['score'])
    print(ele['scan_id'])
    print(ele['text'])
    
    print("=======================================")
    print("\n")
# Out:
# 0192699d1d7ef8374eecf4c069bfa0b8d81442afaef4d3713cfca8ffe95ddf11
#   MARK KORRES
#
#   9561 Arrowhead Dr. Hickory Hills, IL 60457 • (773) 297-3450 • mark@markkorres.com
#
#   Page 1 of 2
#
#   SUMMARY
#
#   An IT Service Management, ITIL certified technical professional with a breadth of experience teaching, designing,
#
#   implementing, and improving IT operations, processes, and frameworks. A leader that emphasizes team success
#
#   and inspires desired outcomes and increased performance with a cross-industry designation and deep experience in
#
#   Life Sciences, Healthcare, Energy, and Insurance/Financial industries for Fortune 500 and large companies.
#
#   Extensive experience leading IT transformations, implementing major initiatives, designing processes, creating
#
#   proposals, responding to RFPs/RFIs, mentoring counselees, and managing infrastructure teams. Recent
#
#   accomplishments include a Continuous Service Improvement implementation that produced a 60% decrease in
#
#   Priority 1 incidents and an 80% improvement in average resolution time and the creation of a three-year roadmap to
#
#   save the client $4.6M annually in addition to $6M in qualitative benefits. Open to travel.
#
#   EXPERIENCE
#
#   ➢ ITIL/ITSM Expertise
#
#   • Led redesign of core ITSM processes including workshops, interviews. Created process documentation, training
#
#   guides and completed train the trainer sessions. Redesigned meta-data for the current and future ITSM tools and
#
#   documented pre-requisites for recommended ITSM tool.
#
#   • Designed and implemented an ITSM governance structure to address ITSM improvements and prioritize
#
#   projects. Mentored client process owners to create improvement projects and charters. Identified 60+ initiatives
#
#   and 20+ projects to support the ITSM Strategy and implement it the over three years.
#
#   • Responsible for regional and global service implementation across 3 regions for trading applications using ITIL
#
#   standards including governance and a standardized CMDB.
#
#   • Developed Service Catalogs, Service Request processes and roadmaps to implement with SLAs and KPIs.
#
#   • Served as IT Service Management Liaison for all Acquisitions and Divestitures.
#
#   ➢ Service Improvement / Application Rationalization / IT Operating Model
#
#   • Led ITSM Tool assessment that included 500+ IT Tools and 380K+ users resulting in $4.6M annual savings.
#
#   • Recommended transition from a legacy tool to ServiceNow to save the organization $1M+ yearly.
#
#   • Assessed current IT Operating Model, including value of major tools and applications for CIO and CFO
#
#   decisions. Developed a plan to reduce IT spend and target a 3% IT cost and a go-forward IT Operating Model
#
#   with a $13M reduction in IT cost. Produced a 14-month roadmap to implement projects and transform to new
#
#   operating model.
#
#   • Lead Strategy to convert from Remedy to ServiceNow, including the definition of Service Catalog offerings,
#
#   data elements and workflow. Coordinated Service Management processes with ServiceNow workflows and
#
#   implemented Incident, Change, Problem, Release, Configuration, Asset, Knowledge, Event, SCM and SLM.
#
#   • Developed and Managed the “Availability is Job #1” Program which resulted in: reduction of P1 Incident Count
#
#   by 60% and P1 Duration by 80%, eliminated outages during planned Infrastructure Maintenance, eliminated
#
#   authentication P1 incidents, Reduced the number P1s due to Change, and reduced the backlog of open Root
#
#   Cause Analysis tickets by 90%.
#
#   ➢ Proposals / RFPs
#
#   • Led team of 20+ to create 70+ page proposal and several supporting presentations to win ServiceNow
#
#   implementation for large financial client.
#
#   • Led large and small teams to create multiple winning proposals for Fortune 500 Life Sciences/Healthcare,
#
#   Energy, and Insurance/Financial clients.
#
#   • RFP Response team member developing and submitting RFP follow-up and clarifying questions.
#
#   • Presentation team member for multiple proposals
#
#   ➢ Assessments / Improvement Roadmaps
#
#   • Led multiple ITSM Maturity Assessments and helped develop and ITSM Maturity Assessment Tool.
#
#   • Led ITSM and PPM Assessments identifying pain points, creating future states, and performing gap analysis.
#
#   • Developed prioritization tools to help clients focus on quick wins and long-term benefits.
#
#   • Created multiple-year roadmaps plotting project sequence and identifying key dependencies and risks.
#
#   MARK KORRES
#
#   9561 Arrowhead Dr. Hickory Hills, IL 60457 • (773) 297-3450 • mark@markkorres.com
#
#   Page 2 of 2
#
#   JOB HISTORY
#
#   ➢ Deloitte Consulting * 7/17 – Present
#
#   Manager – ServiceNow, ITSM and Service Management Practice
#
#   Led engagements for multiple, national, and global Fortune 500 clients (Life Sciences/Healthcare, Financial and
#
#   Energy) to perform ITSM/ITIL/Maturity assessments, gap analysis, and create roadmaps for improvement and
#
#   implementation. Led teams to create Sales Proposals and RFP responses. Served as practice lead for interviewing
#
#   and hiring new resources. Mentored multiple counselees and assisted with career development and firm success.
#
#   ➢ TEK Systems * 8/12 – 7/17
#
#   Managing Consultant – ITIL / IT Service Management
#
#   Served as ITIL and ITSM Subject Matter Expert and Manager. Led several ITSM, ITIL and Service Improvement
#
#   engagements for multiple Insurance/Financial Chicago area companies.
#
#   ➢ The ACE Group * 7/11 – 8/12
#
#   Service Manager, Combined Insurance, North America
#
#   Implemented a Service Improvement Program to streamline service processes, eliminate impactful outages and
#
#   increase overall availability. Instituted a Communication Policy for all desktop distributions reducing the number of
#
#   secondary distributions and outages due to lack of application access.
#
#   ➢ TEK Systems * 4/10 – 7/11
#
#   Managing Consultant – ITIL / IT Service Management
#
#   Served as ITIL and ITSM Subject Matter Expert and Manager. Led several ITSM, ITIL and Service Improvement
#
#   engagements for multiple Insurance/Financial Chicago area companies.
#
#   ➢ Fruition Partners * 8/07 – 4/10
#
#   Consultant – ITIL / IT Service Management / ServiceNow
#
#   Led engagements for multiple, national, and global clients (Travel, Financial and Energy) to perform
#
#   ITSM/ITIL/Maturity assessments, gap analysis, and create roadmaps for improvement and implementation. Led
#
#   teams to create Sales Proposals and RFP responses. Taught ITIL certification classes. Team member selected to
#
#   review first ServiceNow Administration Guide.
#
#   ➢ Northern Trust * 2/03 – 8/07
#
#   Vice-President, Certification/Deployment Coordinator
#
#   Designed and Implemented new certification and release/deployment process for all desktop applications and
#
#   managed 800+ applications for 14K+ endpoints world-wide. Planned 4K+ deployments/certifications/releases and
#
#   became integral part of Initial Review and PMO processes. Designed and Implemented application/distribution
#
#   tracking database and Deployment Tracking Database to record necessary deployment information
#
#   EDUCATION / CERTIFICATIONS
#
#   • ServiceNow Certified Implementation Specialist
#
#   • ITIL V3 Foundations Certified – Exin U.S.A.
#
#   • Ed Jones "Train-the-Trainer" seminars
#
#   • Illinois Institute of Technology – CS / EE
#
#   • Illinois State Scholar - National Honor Society
#
#   • Who's Who in American High School Students
#
#   GENERAL ASSETS
#
#   * ITIL, Cobit, IT Service Management
#
#   * ServiceNow (ITSM, ITOM, ITBM, CSDM), Remedy, IBM Maximo, LANDesk, Track-IT, Magic Helpdesk
#
#   * Teams, SharePoint, InfoPath, Hyperion, MS Access, HTML, Java Scripts, Citrix
#
#   * Windows, Microsoft Office, MS Project, Visio, Exchange, Lotus Notes, Google Apps, QuickBooks, Timberline
#
#   * Familiar with Novell, UNIX, Linux, MS SQL, Sybase, Oracle, Paradox, CGI, Perl, Cold Fusion, Visual Basic
#
#   * 20 + Years of Management, Training, and Customer Service experience
#
#   * Excellent Organizational, Interpersonal, Training and Developmental Skills
#
#   * A generally nice guy
#
#   FULL CV AND REFERENCES AVAILABLE UPON REQUEST
#
# =======================================
#
#
# 9968c980f4ba28536efc595342379d90d50496036a46588c948ce7dc97bd65df
#   NINA FARKIC 200 Bloomfield Avenue, West Hartford, CT
#
#   (475) 223-6908 | farkic@hartford.edu
#
#   EDUCATION
#
#   UNIVERSITY OF HARTFORD Barney School of Business West Hartford, CT Master in Business Administration 2021 - 2022
#
#   • Concentration in business analytics and marketing • Acquired skills using Forecast X, Data Analysis ToolPak • Dean’s List: Fall 2021
#
#   UNIVERSITY OF HARTFORD Barney School of Business West Hartford, CT Bachelor of Science in Business Administration, Concentration in Marketing 2019 - 2021
#
#   • Overall GPA: 3.76 • Presidential Scholar-Athlete (3.75+ GPA) • Dean’s List: Fall 2019, Spring 2020, Fall 2020, Spring 2021 • Acquired knowledge in computer skills including use of Microsoft Word, Excel, Powerpoint, Google Ads, Twitter
#
#   Analytics WESTERN MICHIGAN UNIVERSITY Haworth College of Business Kalamazoo, MI Bachelor of Science in Business Administration 2017-2019
#
#   WORK EXPERIENCE
#
#   CONSTRUCTION INSTITUTE West Hartford, CT Marketing Intern Sept 2020 - Jan 2021
#
#   • Assist senior management with implement, monitoring, optimizing and creating content on AtlasAms and MyEmma platform • Updating design and content for the event website visionariesforum.org • Working with CI’s Marketing and Communications team to developing a social media campaign • Designing visual assets and content for the program
#
#   Twitter Monetization 2015-2016 • Worked and monitored a high traffic Twitter account • Drove traffic and advertised various companies and their products on platform while earning revenue • Pay per click (PPC) and Cost per Impression (CPI/CPM) advertising
#
#   LEADERSHIP EXPERIENCE
#
#   DIVISION 1 COLLEGIATE BASKETBALL West Hartford, CT University of Hartford 2019 - 2022
#
#   • 3-year scholarship athlete • 40+ hours a week committed to training, meetings, film study, travel and competition • Developed concentration, strong work ethic, and perseverance to meet personal and team goals • Lead tours of facilities to prospective student-athletes and their families • University of Hartford Student-Athlete Newcomer of the Year nominee
#
#   DIVISION 1 COLLEGIATE BASKETBALL Kalamazoo, MI Western Michigan University 2017-2019
#
#   • 2-year scholarship athlete • Mid-American Conference tournament semi-final appearance in 2018 • Most Improved Player 2018
#
#     mailto:farkic@hartford.edu
# =======================================
#
#
# e37c67ba824837aac441207fa829afda4912d2fa749c4f9851449766e03c2e2a
# Salman Ali
#
# Contact: +1 234.564.2066 (salmanali2074@yahoo.com)
#
#
# Objective
#
#
#
# Looking for a role in the field of software engineering where I can achieve solutions to complex business problems using my professional skills and experience.
#
# Professional Experience
#
#
#
# Senior Developer: US Legal Support Inc. Houston TX, Aug 2017 to date.
#
# · Design and developing company flagship product SPOT- Court Reporting micro services-based web applications with .Net Core 3, Angular 8, Visual Studio, Typescript and SQL Server.
#
# · Designed and developed SPOT-Transcription micro services-based web applications in .Net Core 2.1, Angular 7, Visual Studio, Typescript and SQL Server.
#
# · Participate in architecture meetings to design and discuss new features.
#
# · Developed a client portal web site using Angular 6 KindoUI and PrimeNG.
#
# · Design and develop Account Receivable collection system using .Net C# and MVC for Server-side API and Angular 6 for client side.
#
# · Built SQL queries for large data set. Program SQL job to be executed periodically.
#
# · Part of a team which design and develop a system which is used internally for account collection.
#
# · Developed a service to generate invoices as PDF periodically and on-demand.
#
# · Developed a service to generate account statement as EXCEL or CSV periodically and on-demand.
#
# · Working on a system to be used by collectors to process payment in real time and/or to provide audit log for future compliant process.
#
# · Help to manage and maintain CICD (Continuous Integration & Continuous Deployment) pipeline.
#
# · Help to manage and maintain CICD (Continuous Integration & Continuous Deployment) pipeline.
#
# Enterprise Software Engineer: General Motors Financial. Arlington TX, Apr 2017 to Aug 2017.
#
# · Developing commercial funding system for loan & lease using C# ASP .Net and Oracle.
#
# · Used IBM TIBCO services for commercial funding system using TIBCO Designer v5.10.
#
# Senior Software Developer: MobileGuard Inc. New York NY, July 2011 to Mar 2017.
#
# · Designed and developed compliance server in C# ASP .Net for data archiving system.
#
# · Developed web forms-based management console for clients to manage employees.
#
# · Developed custom reporting component using .NET MVC 5 for clients to create and execute reports.
#
# · Implemented REST API in C# ASP .Net to receive data from mobile device in real time.
#
# · Implemented services in C# ASP .Net to import and export arching data from/to files.
#
# · Implemented 3rd party REST API to submit and receive data from carrier network such AT&T and Verizon using C# ASP .NET web API.
#
# · Implemented services in C# ASP .Net to export data to other archiving systems like autonomy, enterprise vault, Symantec, global relay etc.
#
# · Implemented employees & departments reports using ASP .NET MVC 5.
#
# · Designed and developed Android application (targeted for v2.3.6 & above) to capture messages in real time and to deliver to the server in XML format.
#
# · Designed and developed Blackberry OS 7 application to capture messages in real time and to deliver to the server in XML format.
#
# · Designed and implemented a service in C# ASP .NET to receive call record data from AT&T network and store it in MobileGuard server.
#
# · Implemented MobileIron and BES server API in C# ASP .Net to integrate with the system.
#
# · Designed and developed services to integrate the system with Active Directory for administration login purposes.
#
# · Designed and developed SAML based OneLogin service to integrate the system for administration login purposes.
#
# · Developed web form login and integrated with the Active Directory and SAML services.
#
# · Design and implemented a service in C# ASP.Net to search and cache the records from LDAP system to attach the employees’ information in arching data.
#
# · Designed and implemented a service in C# ASP .Net to send SMS alerts periodically (every set interval) to specific carrier mobile’s devices.
#
# · Designed mobile device secure chat application and implemented backend services in C# ASP .Net for messages delivery including Apple push notification service.
#
# · Converting other web form components to ASP .NET MVC 5.
#
# · Maintain servers, update and deploy new changes and fix any problem related to running software on MobileGuard servers or client site on premises servers.
#
# · Maintain Rackspace servers and firewall.
#
# Project Coordinator: A-1 Technology Inc. New York NY, Nov 2010 to July 2011.
#
# · Gathered project requirements and developed requirement documents for clients.
#
# · Involved in identifying the project components and developed the project flow & design documents
#
# · Involved in designing and development of SOA solutions
#
# · Used Rational Rose and Argo-UML for project flow & design documents.
#
# · Used relational database management system include SQL & Oracle
#
# · Designed and involved in layered based project’s component development.
#
# · Built project design documents for implementation based on Agile/scrum methodology.
#
# · Designed and implemented applications’ flow, logic, & algorithms for implementation.
#
# · Setup network components like web server, DNS, routers, firewalls etc.
#
# · Worked on service orientated based architecture for system development.
#
# · Worked on desktop, web, iPhone, & Android projects.
#
# Computer Lab Assistant: New York Institute of Technology, New York NY, May 2010
#
# · Maintain the computer lab and fix any computer system.
#
# · Make sure the computer equipments work properly in classes and fix any problem.
#
# · Make sure that the distance learning classes connected via Internet for lecture and troubleshoot.
#
# · Deliver the computer equipments to the classes for lecture.
#
# Software Developer: CATALYST IT Solutions. Pvt. Ltd. June 2006 to Aug 2008.
#
# I worked on stock trading applications. Developed web application for stock trading system using Java, .Net and SQL. Implemented an application for MetaStock software to provide stock data. I involved in implementing charts and graphs components. Main duties were:
#
# · Redesign and developed content management web form system.
#
# · Developed multithreaded, scalable & time intrinsic web trading server on using .Net C# & SQL.
#
# · Implemented client-side java package for web trading users, using Java J2EE.
#
# · Gathered requirements from clients and identified the requested information.
#
# · Worked in trading environment with network routers & data centers.
#
# Internee Programmer: CATALYST IT Solutions. Pvt. Ltd. Feb 2006 to May 2006.
#
# I used Microsoft Visual Source Safe & Team Serve for development. I developed charts and graphs for web and desktop application. Main duties were:
#
# · Assisted senior developer in design, logic and implementation.
#
# · Redesign the products’ content management application called MasterConsole and re-developed that application as a desktop application using .Net C# & SQL database.
#
# · Developed crystals report for MasterConsole application.
#
# · Developed an installation package for the company’s products using Install Shield Express.
#
# Education
#
#
#
# · 2008- 2010 MS in Information, Network & Computer Security
#
# NYIT - New York Institute of Technology, New York, USA
#
# GPA 3.8 (on scale of 4)
#
# · 2002- 2006 BS in Computer Science
#
# National University – FAST, Karachi, Pakistan
#
# GPA 3.01 (on scale of 4)
#
# Professional Certificate
#
#
#
# · July 2008 - MCTS – Microsoft Certified Technology Specialist
#
# Professional Skills
#
#
#
# · C# .Net, C/C++, Java, ASP .Net, ADO .Net, Blackberry RIM, Android, J2EE,
#
# · .Net Core 2.1 & 3.0
#
# · .Net Framework 2.0, 3.5, 4.0, 4.5, 4.6, 4.7
#
# · Java script, JQuery, HTML, XML, Json, Ajax, Angular 7 & 8, Kindo UI, PrimeNG
#
# · Object oriented programming (OO, OOP), Design Pattern, .Net MVC 5, WCF, SOA, REST API, micro services and web services, WCF, WPF, UML Design, Visio.
#
# · MySql, SQL Server 2008, 2012, 2014, T-SQL, queries, indexes, stored procedures, functions, triggers, SSRS.
#
# · TCP, UDP, IP, HTTP, HTTPS, FTP, SFTP
#
# · Messaging Queues
#
# · Microsoft Visual Studio 2003, 2008, 2012, Eclipse IDE, Blackberry JDE, XCode, Visual Source Code, TypeScript, NetBeans.
#
# · Microsoft’s Team Foundation Server 2010, 2012, SVN Source Control, Git Source Control (Git Kraken)
#
# · Agile Methodology
#
# · Install Shield X Express, MS Access, MS Word, MS Excel, Crystal Reports.
#
# · Multi threaded and real time data processing and delivery.
#
# · Financial/trading system, accounting applications, e-commerce systems, content management applications, Data Archiving system and customized applications.
#
# · AWS, IIS Server, Windows (server 2003, 2008, 20012), LINUX (Cent OS, Fedora), Mac OS.
#
# · Atlassian JIRA, Fogbugz Task Management, Trello Project Management, ServiceNow, Sales Force Desk Support System.
#
# Professional Projects
#
#
#
# SPOT
#
# I am working on this project as a Team lead & Senior Software Engineer in US Legal Support Inc.
#
# This is the company’s flag ship product to provide services to the client on daily bases. This provides a streamline process to the support team to schedule and complete a record retrieval requests for clients. The work involves design and develop a new system with the help of architectures and business analyst to fulfil the requirements of a record retrieval system.
#
# Development tools: .Net Core 3, C# .Net, Angular 8, Rest API/Web services, SQL 2016, Typescript, PrimeNG, using Visual Studio .Net 2019.
#
# Report Generator
#
# I worked on this project as Senior Software Engineer in US Legal Support Inc.
#
# This is the company’s web system for internal users to generate daily, weekly, monthly statement. The work involved to build a system to send generated report to client as email, fax, mail/delivery, allow users to generate new statement on-demand, ability to print statement, log all activity of the user.
#
# Development tools: C# .Net, MVC ASP .Net, Web services, SQL 2016, using Visual Studio .Net 2017.
#
# US Legal Client Portal
#
# I worked on this project as Senior Software Engineer in US Legal Support Inc.
#
# This is the company’s external web form portal for clients to manage the court cases repositories and manage invoices. The work involved to build a system to fulfil clients’ request to provide the case document, upload/update the documents, generate invoices, create dispute for the invoice. Manage application features for internal users.
#
# Development tools: C# .Net, MVC ASP .Net, JQuery, Web services, SQL 2016, using Visual Studio .Net 2017.
#
# DART
#
# I worked on this project as Senior Software Engineer in US Legal Support Inc.
#
# This is the company’s internal web form portal for internal users to request court case’s record retrieval or some services (video recording etc.) for court case, manage the cases, and view and pay invoices. The work involved to build a system to fulfil clients’ request to start a new case, add/update case documents, schedule court case service and pay invoices.
#
# Development tools: Angular 5, Visual Studio Code, C# .Net, MVC ASP .Net, Web services, SQL 2016, using Visual Studio .Net 2017.
#
# Commercial Vehicle Origination System (CVOS)
#
# I worked on this project as Enterprise Software Engineer – Funding in GM Financial.
#
# This was the company’s major web form portal for commercial/business loan and lease applications. The work involved to build a system to process clients’ applications for loan/lease. Funder used this system to validate the applicant’s eligibility. This system used some other APIs to get the client’s credit score from different bureau.
#
# Development tools: C# .Net, ASP .Net, Web services, Oracle 12c, XML using Visual Studio .Net 2015.
#
# Data Archiving System
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# This is a company’s flagship web form portal for corporate clients. The work included to provide interface to manage the employee devices and to view the captured messages. Provide different level of access for help desk, compliance and administration purpose. Multiple reports were developed using MVC design pattern. Contains services to import data from different streams and export the archived messages in different format such as xml, mime or CSV to client’s premises or archiving like Enterprise Vault, Globle Rely, ProofPoint, Autonomy etc.
#
# Development tools: C# .Net, ASP .Net, MVC 5, MS SQL server 2012, Json/XML services using Visual Studio .Net 2012.
#
# NetGuard – Carrier Based (AT&T and Verizon)
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# This is an important component of the MobileGuard system. The worked involved implementing the AT&T and Verizon carrier API services to receive data. The services include submitting the mobile devices phone number to provision the device for message monitoring and complete the authorization process and then get the messages for authorized devices from the carrier network.
#
# Development tools: C# .Net, ASP .Net, MS SQL server 2012, Json services using Visual Studio .Net 2012.
#
# iPhone – iTunes Data Export Desktop Application
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# It is a desktop application and a component of the MobileGuard system. The concept is that iTunes automatically backup the iPhone messages when user connects the iPhone device to iTunes. I implemented this application to read the iTunes backup of iPhone devices and deliver the data to the MobileGuard server in XML format. The application was designed and implemented to run as a Service and it checks the iTunes backup every five minutes and if changes are found then new backed up messages are deliver to the server.
#
# Development tools: C# .Net, SQLite, XML services using Visual Studio .Net 2012.
#
# MobileGuard Consumer System
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# This is a web form portal for personal users who want to capture and record their and family’s mobile messages for personal and business security. The work included, to provide interface to access the archived messages and add/edit the new device. Also provide message export to forward archived message to their email address.
#
# Development tools: C# .Net, ASP .Net and XML services using .Net 2010 and MS SQL server 2012.
#
# MobileGuard – Android application
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# This is a mobile device application. The work included, capture device SMS messages, and call log. Also include capturing IM messages like Yahoo, GTalk, BBM, PIN, and Whatsapp. I developed this application for blackberry and android devices.
#
# Development tools: Eclipse, Android Java, SQLite and XML formatted data.
#
# MobileGuard – Blackberry application
#
# I worked on this project as Senior Software developer in MobileGuard.
#
# This is a mobile device application. The work included, capture device SMS messages, and call log. Also include capturing IM messages like Yahoo, GTalk, BBM, PIN, and Whatsapp. I developed this application for blackberry and android devices.
#
# Development tools: Eclipse, Blackberry Java plugin, SQLite and XML formatted data.
#
# myregistry.com
#
# I worked on this project as a Developer & Project Coordinator in A1-Technology.
#
# This was an e-commerce web application to add and purchase personal registry items. The work included, creating new web forms and updates existing according to the requirement on the main website and content management system of the website.
#
# Development tools: C# .Net, ASP .Net, xml services, Java script, Ajax, MS SQL 2008 using Visual Studio 2010
#
# Web site Migration
#
# I worked on this project as a Developer & Project Coordinator in A1-Technology.
#
# This is migration project for myregistry.com website. I moved the web sites from web server and Images server from ftp server onto a single server. Previously the web and ftp were running on 32 bit windows 2003 server with IIS 6. I did move them on 64 bit windows 2008 with IIS7. The migration included, moving the websites, Scheduled jobs, services, system users and assigned privileges to particular IPs for special user to access the content management site.
#
# Development tools: Rackspace servers, firewall, Windows services installation, Task scheduler, Remote desktop, MS SQL server 2008 backup and migration, MS Office.
#
# Stevenslee.com
#
# I worked on this project as Project Coordinator in A1-Technology.
#
# This is a website project to renew the site according to the new design. I did work on all pages to convert them according to new design and color scheme. Most of the pages were on HTML and asp.
#
# Development tools: ASP, HTML, java script and MS Access database.
#
# Ultimate Bubble Popper
#
# I worked on this project as Project Coordinator in A1-Technology.
#
# It is a game application for Android mobile devices. The game contains a table with full of different colors of bubble and the goal is to clear all bubbles by popping them. User has to pop a group (minimum two) of same color bubbles and bubbles must be together on the table. The important feature of the game is, the bubbles fall on the empty space of popped bubbles, base on the gravity. User gets more points if pops more bubbles at a time. The game consist of two levels Easy & Hard. Hard level shows some non-pop-able bubbles that make the game more interesting. The game is in android market under the name Ultimate Bubble Popper.
#
# Development tools: Eclipse, Android Java, SQLite, MS Office.
#
# POS – Point of Sale System
#
# I worked on this project as Project Coordinator in A1-Technology.
#
# This was an e-commerce application for a Point-Of-Sale system to sale liquor products. This was a project for liquor store to sell liquor products. This project has two components, Website & POST (Point of Sale Terminal). Website includes the POST, employees and customer management system. Both components were built as layered based approach. Website contains different access roles for different users of the websites. And POST is desktop application for transactions and to provide all commons action for a store to process an order. Both components use same database. Website accesses the database to manage user & employees, for applying restriction on POST, & reporting purpose. The POST uses the database to validate sale person actions and storing transactions information
#
# Development tools: C# .Net, ASP .Net, MS SQL 2008, JavaScript using Visual Studio 2010.
#
# Trade Cast
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This is web-based stock trading software. User can view the stock rates and can submit trade order in real time stock market from the web browser. I developed both server side and client side’s applications; in which server sends stock market data/rates to client by push technology and send/receive user order to/from market. I also developed java plug-in for web browser, to communicate with application server through TCP, to get real time stock quotes for web page.
#
# Development tools: C# .Net, MS SQL server 2005, java plug-in using Java 1.4 SDK, & Visual Studio 2008.
#
# Trade Cast Client Active-X Control for Order Placement
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# Data flows very fast over TCP connection so the idea was to establish a TCP connection to place stock order to the server and stock exchange. But website does not allow TCP connections from client side. The active-x component was designed and I implemented to establish a TCP connection with the order processing server when user starts the web session. The active-x control is downloaded when user logon to the Trade Cast website first time. I used Javascript to call the active-x control functions. Active-x control has an event that was implemented on the HTML side of the website. The active-x control triggers the event to deliver the data to the webpage.
#
# Development tools: VC++ 6.0, ASP and using Visual Studio 2005.
#
# Upload-Positions
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This is a small web application for stock brokers to upload/update their branch’s accounts position (credit/debit) in head office database. This web site is hosted in head office’s web server. This site includes content management, for head office IT manager, to create/update broker login account and also include an important Upload page for brokers, the upload page take input files (xml or specific text format) from broker, and then parse and upload account’s new position in head office’s database.
#
# Development tools: C# .Net, ASP .Net 2005 with MS SQL 2005, and using Visual Studio 2005.
#
# Master Console
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This is web form administration panel software for CATALYST Trading System. This software is used to restrict and resume client trading applications activities, during real time stock market. This application performs many operations like block/resume account or user from trading, view and print log etc. I redesign this system from web based to make an application.
#
# Development tools: C# .Net 2005 with MS SQL 2005 using Visual Studio 2005.
#
# Charts and Graphs
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This software provides stock market’s real time Chart and Graphs. I developed these charts and graphs for windows, web and mobile devices. This software provides both Intraday and Inter day Charts and Graphs of stock market data.
#
# Development tools: C# .Net with MS SQL 2005, ChartDirector tool and using Visual Studio 2005.
#
# Software Deployment and Software Updates
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# I made software’s installation packages using Install Shield X Express. I also developed software update plug-in to update any application on the fly. I implemented two applications one for update server and second update pug-in for applications. This software is customizable so that update plug-in can be attached with any application to update it from the server.
#
# Development tools: C# .Net 2005 for application plug-in extension and C# .Net for update server, using Visual Studio 2005.
#
# Intra Day Feed Provider for MetaStock Professional
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# MetaStock is well known international software to view trading activities. I developed a small application to provide stock market’s intraday feed to MetaStock Professional application.
#
# Development tools: C# .Net 2005, MS SQL server 2005, MetaLib library, using Visual Studio 2005.
#
# Voice Chatting Software
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This is voice chatting software to use over LAN. Users are able to view all online users, can do voice chatting as individual and as conference.
#
# Development tools: Java J2EE with eclipse for windows and Linux operating systems.
#
# Network Monitoring
#
# I worked on this project as Software Developer in Catalyst IT Solutions.
#
# This was an application to look for the network activities and provide real time information. The two modules, server and client developed on java J2EE. And the application was displaying/scanning DNS, Internet, System Port & client system availability.
#
# Development tools: Java J2EE with eclipse.
#
# =======================================
#
#
# 0c415eb722c2c93929f517bcc834b8f74919c8194be662f38e4f09d8f8d64d00
#   STEPHEN A. VICKNAIR, CPA (678) 215-1719
#
#   stevevicknair@gmail.com
#
#   PROFESSIONAL ASSETS AND SKILLS
#
#   • Certified Public Accountant, State of Georgia
#
#   • Key strengths include excellent analytical and organizational skills, decision making capabilities and interpersonal communication/relationships while building trust, developing productive relationships and mentoring/coaching staff to maximize productivity
#
#   • Manage staff including payroll, accounts receivable, accounts payable and human resources
#
#   • Establish internal controls for financial reporting
#
#   • Review and analyze financial information to prepare monthly, quarterly and annual financial
#
#   statements; prepare financial analysis for management
#
#   • Risk and claims management for a firm in a captive insurance environment
#
#   • Maintain banking and surety relationships
#
#   RELATED EXPERIENCE CORE ROOFING SYSTEMS, ALPHARETTA, GA, February 2009 to September 2021 A commercial roofing contractor providing new, re-roofing and repair services throughout the southeast. Position: Controller
#
#   • Manage financial reporting in accordance with generally accepted accounting principles (GAAP) using the percentage-of-completion method and income tax basis accounting
#
#   • Manage audit/review and multi-state tax compliance
#
#   • Evaluate and improve financial reporting using various software packages
#
#   • Manage human resources, insurance and OSHA reporting
#
#   • Manage accounts receivable, payable and payroll with a small staff
#
#   • Secured significant Paycheck Protection Program loan and subsequent forgiveness JULIAN LECRAW AND COMPANY, LLC, ATLANTA, GA, May 2007 to December 2008 A developer/manager of multi-family communities and commercial projects in the southeast. Position: Controller (June 2008 to December 2008)
#
#   • Manage financial reporting for corporate, property, development and construction accounting in accordance with generally accepted accounting principles (GAAP) and income tax basis of accounting.
#
#   • Manage accounts payable and payroll functions
#
#   • Manage income tax preparation for all corporate and property entities
#
#   • Manage external audits and reviews including disclosures
#
#   • Manage process of recording contributions, distributions and investor accounting
#
#   • Develop initiatives to gain efficiencies in operation including implementation of electronic document management systems, establishing policies & procedures
#
#   • Project manager for development of a database of investors, joint ventures, mortgages, contributions and distributions
#
#   • Develop problem-solving and decision making skills for staff via accounting roundtables and one on one training
#
#   Position: Director of Property Accounting (May 2007 to June 2008)
#
#   • Manage financial reporting of for-rent and for-sale properties in compliance with generally accepted accounting principles (GAAP) or income tax basis using Intuit/MRI
#
#   • Manage a staff of 10
#
#   • Manage income tax preparation for all properties and entities including a significant number of legacy ventures; manage external audit process
#
#   EASTERN BAND OF CHEROKEE INDIANS, CHEROKEE, NC, September 2004 to May 2007 A federally recognized Indian tribe with approximately 1,000 employees with gaming operations that provides significant revenues for enrolled members and tribal operations. Position: Accounting Manager
#
#   • Manage general accounting and high volume accounts payable, payroll and per capita distributions using an ERP system
#
#   • Manage preparation of monthly and annual financial statements using fund accounting in accordance with governmental accounting standards board (GASB)
#
#   • Manage staff of 11-14
#
#   • Provide support to programs in budget development and amendments
#
#   • Monitor and reconcile grant income and related expenditures
#
#   • Coordinate external audit including preparation of Management Discussion and Analysis (MD&A)
#
#   • Project manager for acquisition and implementation of electronic document management system
#
#   STEPHEN A. VICKNAIR, CPA, MURPHY, NC, January 1992 to September 2004 A Certified Public Accountant whose practice focused on income tax planning/preparation and the compilation/review of financial statements Position: Sole Practitioner STEPHEN A. VICKNAIR, ATLANTA, GA, October 1988 to January 1992 Self-employed business owner KERN & COMPANY, INC, ATLANTA, GA, September 1979 to October 1988 A commercial real estate firm which developed in excess of 4 million square feet of business park, office, retail and industrial space in Atlanta Position: Senior Vice President – Finance As Senior Vice President-
#
#   • Established corporate policy and strategic planning
#
#   • Acquisition of non-development assets
#
#   • Disposition of commercial real estate
#
#   • Preparation of financial statements and income tax returns for company founder As Vice President, Finance-
#
#   • Overall financial planning and reporting for the company, real estate limited partnerships and the company founder
#
#   • Financial analysis of proposed real estate developments
#
#   • Negotiated financing with joint venture partners and lenders
#
#   • Disposition of real estate JOHNSTOWN PROPERTIES, INC, ATLANTA, GA, September 1977 to August 1979 A privately-owned multi-family management firm with approximately 16,000 units held in private limited partnerships and publicly owned investments Position: Controller HALPERN ENTERPRISES, INC, ATLANTA, GA, September 1969 to August 1977 A privately-owned developer/operator of shopping centers throughout metropolitan Atlanta Position: Controller EDUCATION
#
#   • B.B.A. in Accounting, Georgia State University, Atlanta, GA, August 1977
#
#   • Completed first year of Executive MBA program at Georgia State University, June 1987
#
# =======================================
#
#
# 847db224d5e72d1bb5cc0532aae93bbd3fd0ee313e52ae07fc4a9569f5f01c5e
#   ADAM ZOLLARS 4204 N Creek Drive, Mt. Jul iet, TN 37122 | (614) 256-3995 | adamzollars@gmail.com
#
#   S U M MA R Y
#
#   IT Customer Service Leader with experience in building, managing, and developing customer-centric and data-driven teams in Service Desk, Desktop, Operations, and Identity & Access Management.
#
#    I support the “Shift Left” approach to IT Service Management, where the goal is to move problem resolution and other activities as close as possible to the end user to save costs and improve customer service experience. I believe ITIL provides an effective framework to support “Shift Left” and am certified in ITIL Foundations v4, ITIL Service Operations, and HDI Support Center Director.
#
#    I believe effective IT Support teams are advocates for their customers, internal or external. We should always understand what’s important to the people we serve and work on their behalf to resolve issues that impede them, or deliver service that adds value. There should be a formalized Business Relationship Management component to this engagement to facilitate regular feedback and alignment.
#
#    I believe in data-driven approaches to identifying service opportunities and measuring results. Everyone should understand and support the KPIs applicable for their area, and be transparent in reviewing those results with your customer. Where applicable, formalize these measures as Service Level Agreements with the customer.
#
#    I believe in being financially-efficient, actively measuring value as a combination of services provided and cost to deliver.
#
#    I understand key regulations that govern user access management in retail, and have several years of experience with PCI and SOX compliance and audit processes.
#
#   E XP E R IE NCE
#
#   Director – IT Service Desk at Ingram Content Group 7/2018 – 6/2020
#
#   What I was hired to do:
#
#    Transform a legacy Help Desk, Desktop, and Operations support function into a more effective IT Services group focused on Incident resolution and customer service. The scope of responsibility has expanded to include ticketing system administration, Change and RCA process management.
#
#    My organization consists of 7 teams and 32 employees, mostly in Nashville.
#
#   Key contributions:
#
#    Doubled first- level resolution percentage within 8 months by establishing performance goals, updating personnel and position expectations, and knowledge sharing with other IT teams
#
#    Engaged directly with publishers in delivering an Ingram-developed mobile point of sale system for use at academic conferences – 11/2018
#
#    Took over management of the IT ticketing system (Jira), leading the effort to implement new Change and Problem processes – 3/2019
#
#    Led an initiative to deploy MS Teams for chat and audio conferencing to over 2000 Ingram associates – 5/2019
#
#    Took over management of all 6 Zendesk instances in use by different Ingram business units – 9/2019
#
#   Director – IT Customer Service at ascena Retail Group
#
#   10/2013 - 6/2018
#
#   What I was hired to do:
#
#    Lead the formation and continuing expansion of the ascena Service Desk as the first point of contact for Point of Sale, Distribution Center, and Corporate Office technology for ascena Retail brands.
#
#    My scope of responsibility expanded to include Identity & Access Management and HEAT ticketing system development and support. This was a geographically distributed team of ~100 associates providing 24x7 first-level technical support, identity management, and critical incident management to ascena employees/contractors in all store and corporate office locations.
#
#   Key contributions:
#
#    Developed the ascena Service Desk’s staffing model based on current and projected contact volumes and Service Level Targets - 10/2013
#
#    Negotiated an exclusive staffing agreement for Tier 1 Service Desk contractors, then partnered with ascena HR and the staffing firm to fill a
#
#   total of 20 contract and full-time positions between November 2013-January 2014
#
#    Transitioned POS support from the Charming Shoppes Help Desk in Bensalem, PA to ascena Service Desk - 2/2014
#
#    Insourced first-level support for 975 Justice stores from Micros Retail as the brand upgraded from Store21 to OrPOS - 11/2014-6/2015
#
#    As part of our Tata Consulting staffing implementation, took over management of an offshore Identity and Access Management team with responsibility for Active Directory, Exchange, and other business application account provisioning for all brands. At the same time, expanded ascena Service Desk support to 24x7x365 and took over management of major incidents – 2/2015
#
#    Implemented xMatters and integrated with HEAT to streamline IT on-call escalation and major incident management processes – 9/2015
#
#    Assumed first level technical support for eCommerce as each brand migrated from Fry or Speed to ATG - 1/2016
#
#    Increased utilization of Self Service for request management from 25% in 2016 to 50% in 2017 in an effort to better manage request approval workflow and improve SOX compliance.
#
#    Integrated the Maurices POS level 1 support team in Duluth, MN into the ascena Service Desk - 3/2017
#
#    Eliminated Fujitsu level 1 POS support in Dallas, TX and insourced support for Dressbarn stores into the ascena Service Desk – 6/2017
#
#   Manager – IT Service Delivery at Express 2/2012 — 10/2013
#
#   What I was hired to do:
#
#    Manage Home Office Support team (desktop/laptop support) with responsibility for purchasing, imaging, deployment, patching, security and break/fix support of ~950 Windows/80 Mac OSX workstations using SCCM, Casper, VMWare View VDI, and McAfee ePO. This team was also responsible for provisioning of all Active Directory and Exchange accounts, and Cisco desk phones
#
#    In this role, I managed 5 direct reports (3 FTE and 1 Contractor in Columbus, 1 FTE in New York).
#
#   Key contributions:
#
#    Reorganized team from a single tier into a two-tier structure with new job descriptions, development plans and core responsibilities. Reduced average open Incident/Work Order count from 100 in 4/2012 to 25 in - 4/2013
#
#    Assumed responsibility for billing management and end user support of company-issued smartphones - 4/2013
#
#    Airwatch MDM and Cisco VPN deployed to all District Managers to enable access to real-time sales updates - 2/2013
#
#    Partnered with Network team to deploy Cisco Jabber to 700 workstations for instant messaging, video, and softphone capability - 2/2013
#
#    Lead project to implement and deploy Boardvantage to Board of Directors’ iPads in - 11/2012
#
#   Support Supervisor at Abercrombie & Fitch 10/2008 — 2/2012
#
#   What I was hired to do:
#
#    Manage Mac environment which included ~350 Macs clients, 4 OSX file servers, XSAN, iCal, Open Directory, Casper, Netboot, and AFP/SMB file sharing
#
#    Responsible for the full lifecycle of budgeting, purchasing, imaging, deployment/support and decommissioning of all Mac clients
#
#   Key contributions:
#
#    Implemented Casper for Mac management in 2008 on XServe, migrated to Windows Server 2008 in 2011
#
#    Implemented MobileIron to manage iOS and Android devices in 2011
#
#    Upgraded all Mac clients from OSX 10.4 to OSX 10.5 or 10.6 in 2009
#
#   Desktop Analyst III at Tween Brands 6/2005 — 10/2008
#
#   What I was hired to do:
#
#    Tier 2 desktop/laptop support for 450 Windows and 50 Mac clients at Limited Too/Justice home office
#
#    Manage corporate-issued mobile devices (Blackberries, Treos, cell phones, and wireless broadband adapters)
#
#   Key contributions:
#
#    Project lead for Windows 2000 to Windows XP upgrade for 450 systems 8/2005
#
#    Created Group Policies to deploy software through Active Directory
#
#    Developed computer inventory tracking system using a WMI query tool and Microsoft Access
#
#    Build/maintain all Windows and Mac images using Ghost and Carbon Copy
#
#    Manage Windows, Office, and McAfee Virus Scan patching with SUS and ePO
#
#    Upgraded all Macs from OS X 10.3 to 10.4 in 2007
#
#   Help Desk Analyst at Victoria’s Secret and Limited Brands 11/1998 - 6/2005
#
#   What I was hired to do:
#
#    First level technical support for employees at all Limited Brands corporate offices in Columbus, New York, Rio Rancho, NM and Kettering, OH
#
#   Key Contributions:
#
#    Developed a consolidated searchable knowledgebase in MS Access.
#
#    Created a formal new hire onboarding and training program
#
#    Developed an MS Access based reporting system to provide IT service metrics to stakeholders at each brand
#
#   E DU CA T IO N
#
#   Bachelor of Science in Communication from Ohio University, Athens OH
#
#   Major: Audio Engineering, Minor: Psychology
#
#   Professional Training and Certifications
#
#   ITIL Foundations v4
#
#   ITIL Service Operations
#
#   HDI Service Center Director
#
#   Mac OSX Deployment 10.5
#
#   Apple Certified Technical Coordinator 10.5
#
#   Microsoft Certified Desktop Support Technician Windows XP
#
# =======================================

# %%
import requests
import mimetypes
from requests import Request, Session
import asyncio
import os

# %%
files_path = "D:\\files\\nlp6"
file1 ="4SD.ThreeStoogesbw.OL.txt.txt"
file2 = "612CCORSONY2410.txt.txt"
file3 = "14070413.fs.txt"

fin = open(os.path.join(files_path, file1), 'rb')#9190014364 9190077791 9190029216 9200000032
minuta = open(os.path.join(files_path, file2), 'rb')
data1=fin.read()
data2=minuta.read()
data3 = open(os.path.join(files_path, file3), 'rb').read()
payload_dict={'file1': data2, 'file2': data3}

# %%
url = "http://localhost:5006/api/compare_files" 

try:
    r = requests.post(url, data=payload_dict)#files=files)
    print(eval(r.text))
finally:
    pass
# Out:
# {
#   "status": "SUCCESS",
#   "results": {
#     "Cosine-Similarity": 0.8714479207992554,
#     "Simple Ratio": 16,
#     "Partial Ratio": 29,
#     "Token Sort Ratio": 15,
#     "Token Set Ratio": 16,
#     "Partial Token Sort Ratio": 40
#   }
# }
